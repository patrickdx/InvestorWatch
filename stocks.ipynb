# %%
import sys
import os 
from finvizfinance.news import News
from finvizfinance.screener.overview import Overview
from finvizfinance.quote import finvizfinance
import pandas as pd 
from datetime import datetime
import time

PATH = 'stocks/tickers'

if not os.path.exists(PATH): os.makedirs(PATH)

# %%
market_cap = {
        'Mega' : 'Mega ($200bln and more)',
        'Large' : '+Large (over $10bln)',
        'Mid' : '+Mid (over $2bln)',
}

foverview = Overview()
filters_dict = {'Market Cap.': market_cap['Large'], 'Country': 'USA'}

foverview.set_filter(filters_dict=filters_dict)
df = foverview.screener_view() 
df['Market Cap (billions)'] = df['Market Cap'] / 1e9
df.drop(columns = ['P/E', 'Change', 'Market Cap', 'Volume'], inplace = True)

df.to_csv('stocks/stocks.csv', index = False)                               # sink all marketcap+ stocks
# Out:
# [Info] loading page [#############################-] 35/36

# %%
df = pd.read_csv('stocks/stocks.csv')
df.sort_values(by='Market Cap (billions)', ascending= False)
# Out:
#     Ticker                                  Company                  Sector  \
# 3     AAPL                                Apple Inc              Technology
# 465   NVDA                              NVIDIA Corp              Technology
# 436   MSFT                    Microsoft Corporation              Technology
# 39    AMZN                           Amazon.com Inc       Consumer Cyclical
# 297   GOOG                             Alphabet Inc  Communication Services
# ..     ...                                      ...                     ...
# 615    TPX           Tempur Sealy International Inc       Consumer Cyclical
# 270   FOUR                      Shift4 Payments Inc              Technology
# 441   MTSI  MACOM Technology Solutions Holdings Inc              Technology
# 197    DOX                               Amdocs Ltd              Technology
# 706   CELH                     Celsius Energy Drink      Consumer Defensive
#
#                                Industry Country   Price  Market Cap (billions)
# 3                  Consumer Electronics     USA  232.87                3540.82
# 465                      Semiconductors     USA  136.02                3223.93
# 436           Software - Infrastructure     USA  418.79                3144.80
# 39                      Internet Retail     USA  201.45                2104.79
# 297      Internet Content & Information     USA  169.43                2029.12
# ..                                  ...     ...     ...                    ...
# 615  Furnishings, Fixtures & Appliances     USA   57.86                  10.11
# 270           Software - Infrastructure     USA  111.34                  10.08
# 441                      Semiconductors     USA  135.37                  10.04
# 197           Software - Infrastructure     USA   87.30                  10.02
# 706           Beverages - Non-Alcoholic     USA   29.75                   7.05
#
# [707 rows x 7 columns]

# %%
df = pd.read_csv('stocks/stocks.csv')

def get_news(df : pd.Series):       # sinks new news sources to csv files
    try:
            
        time.sleep(0.2)
        file = f"{PATH}/{df['Ticker']}.csv"
        whitelist = ['Bloomberg', 'Reuters']
        news_df = finvizfinance(df['Ticker']).ticker_news()
        news_df = news_df[news_df['Source'].isin(whitelist)]              # whitelist

        today = datetime.today()                                           # filter new news inbetween modified date and today
        last_modified = datetime.fromtimestamp(os.path.getmtime(file))
        news_df = news_df[(news_df['Date'] >= last_modified) & (news_df['Date'] <= today)].sort_values('Date')

        if not os.path.exists(file):
            news_df.to_csv(file, index = False)  
            print(f'created {file} ...')

        news_df.to_csv(file, mode='a', header=False, index=False)         # append/remove header
        print(f'found {len(news_df)} new sources to {file} ...')   

    except Exception:
        print(Exception)

    

df.apply(get_news, axis = 1)            # apply get_news() on every row


# get_news(df.iloc[465])
# Out:
# found 0 new sources to stocks/tickers/A.csv ...
# found 0 new sources to stocks/tickers/AA.csv ...
# found 0 new sources to stocks/tickers/AAON.csv ...
# found 0 new sources to stocks/tickers/AAPL.csv ...
# found 0 new sources to stocks/tickers/ABBV.csv ...
# found 0 new sources to stocks/tickers/ABNB.csv ...
# found 0 new sources to stocks/tickers/ABT.csv ...
# found 0 new sources to stocks/tickers/ACI.csv ...
# found 0 new sources to stocks/tickers/ACM.csv ...
# found 0 new sources to stocks/tickers/ADBE.csv ...
# found 0 new sources to stocks/tickers/ADI.csv ...
# found 0 new sources to stocks/tickers/ADM.csv ...
# found 0 new sources to stocks/tickers/ADP.csv ...
# found 0 new sources to stocks/tickers/ADSK.csv ...
# found 0 new sources to stocks/tickers/AEE.csv ...
# found 0 new sources to stocks/tickers/AEP.csv ...
# found 0 new sources to stocks/tickers/AFG.csv ...
# found 0 new sources to stocks/tickers/AFL.csv ...
# found 0 new sources to stocks/tickers/AFRM.csv ...
# found 0 new sources to stocks/tickers/AGR.csv ...
# found 0 new sources to stocks/tickers/AIG.csv ...
# found 0 new sources to stocks/tickers/AIT.csv ...
# found 0 new sources to stocks/tickers/AIZ.csv ...
# found 0 new sources to stocks/tickers/AJG.csv ...
# found 0 new sources to stocks/tickers/AKAM.csv ...
# found 0 new sources to stocks/tickers/ALAB.csv ...
# found 0 new sources to stocks/tickers/ALB.csv ...
# found 0 new sources to stocks/tickers/ALGN.csv ...
# found 0 new sources to stocks/tickers/ALL.csv ...
# found 0 new sources to stocks/tickers/ALLY.csv ...
# found 0 new sources to stocks/tickers/ALNY.csv ...
# found 0 new sources to stocks/tickers/ALSN.csv ...
# found 0 new sources to stocks/tickers/AMAT.csv ...
# found 0 new sources to stocks/tickers/AMD.csv ...
# found 0 new sources to stocks/tickers/AME.csv ...
# found 0 new sources to stocks/tickers/AMGN.csv ...
# found 0 new sources to stocks/tickers/AMH.csv ...
# found 0 new sources to stocks/tickers/AMP.csv ...
# found 0 new sources to stocks/tickers/AMT.csv ...
# found 0 new sources to stocks/tickers/AMZN.csv ...
# found 0 new sources to stocks/tickers/ANET.csv ...
# found 0 new sources to stocks/tickers/ANSS.csv ...
# found 0 new sources to stocks/tickers/AOS.csv ...
# found 0 new sources to stocks/tickers/APD.csv ...
# found 0 new sources to stocks/tickers/APG.csv ...
# found 0 new sources to stocks/tickers/APH.csv ...
# found 0 new sources to stocks/tickers/APO.csv ...
# found 0 new sources to stocks/tickers/APP.csv ...
# found 0 new sources to stocks/tickers/AR.csv ...
# found 0 new sources to stocks/tickers/ARCC.csv ...
# found 0 new sources to stocks/tickers/ARE.csv ...
# found 0 new sources to stocks/tickers/ARES.csv ...
# found 0 new sources to stocks/tickers/ARMK.csv ...
# found 0 new sources to stocks/tickers/ATO.csv ...
# found 0 new sources to stocks/tickers/ATR.csv ...
# found 0 new sources to stocks/tickers/AUR.csv ...
# found 0 new sources to stocks/tickers/AVB.csv ...
# found 0 new sources to stocks/tickers/AVGO.csv ...
# found 0 new sources to stocks/tickers/AVTR.csv ...
# found 0 new sources to stocks/tickers/AVY.csv ...
# found 0 new sources to stocks/tickers/AWK.csv ...
# found 0 new sources to stocks/tickers/AXON.csv ...
# found 0 new sources to stocks/tickers/AXP.csv ...
# found 0 new sources to stocks/tickers/AYI.csv ...
# found 0 new sources to stocks/tickers/AZO.csv ...
# found 0 new sources to stocks/tickers/AZPN.csv ...
# found 0 new sources to stocks/tickers/BA.csv ...
# found 0 new sources to stocks/tickers/BAC.csv ...
# found 0 new sources to stocks/tickers/BAH.csv ...
# found 0 new sources to stocks/tickers/BALL.csv ...
# found 0 new sources to stocks/tickers/BAX.csv ...
# found 0 new sources to stocks/tickers/BBY.csv ...
# found 0 new sources to stocks/tickers/BDX.csv ...
# found 0 new sources to stocks/tickers/BEN.csv ...
# found 0 new sources to stocks/tickers/BEPC.csv ...
# found 0 new sources to stocks/tickers/BF-A.csv ...
# found 0 new sources to stocks/tickers/BF-B.csv ...
# found 0 new sources to stocks/tickers/BG.csv ...
# found 0 new sources to stocks/tickers/BIIB.csv ...
# found 0 new sources to stocks/tickers/BJ.csv ...
# found 0 new sources to stocks/tickers/BK.csv ...
# found 0 new sources to stocks/tickers/BKNG.csv ...
# found 0 new sources to stocks/tickers/BKR.csv ...
# found 0 new sources to stocks/tickers/BLD.csv ...
# found 0 new sources to stocks/tickers/BLDR.csv ...
# found 0 new sources to stocks/tickers/BLK.csv ...
# found 0 new sources to stocks/tickers/BMRN.csv ...
# found 0 new sources to stocks/tickers/BMY.csv ...
# found 0 new sources to stocks/tickers/BR.csv ...
# found 0 new sources to stocks/tickers/BRBR.csv ...
# found 0 new sources to stocks/tickers/BRK-A.csv ...
# found 0 new sources to stocks/tickers/BRK-B.csv ...
# found 0 new sources to stocks/tickers/BRO.csv ...
# found 0 new sources to stocks/tickers/BSX.csv ...
# found 0 new sources to stocks/tickers/BSY.csv ...
# found 0 new sources to stocks/tickers/BURL.csv ...
# found 0 new sources to stocks/tickers/BWXT.csv ...
# found 0 new sources to stocks/tickers/BX.csv ...
# found 0 new sources to stocks/tickers/BXP.csv ...
# found 0 new sources to stocks/tickers/C.csv ...
# found 0 new sources to stocks/tickers/CACI.csv ...
# found 0 new sources to stocks/tickers/CAG.csv ...
# found 0 new sources to stocks/tickers/CAH.csv ...
# found 0 new sources to stocks/tickers/CARR.csv ...
# found 0 new sources to stocks/tickers/CART.csv ...
# found 0 new sources to stocks/tickers/CASY.csv ...
# found 0 new sources to stocks/tickers/CAT.csv ...
# found 0 new sources to stocks/tickers/CAVA.csv ...
# found 0 new sources to stocks/tickers/CBOE.csv ...
# found 0 new sources to stocks/tickers/CBRE.csv ...
# found 0 new sources to stocks/tickers/CCI.csv ...
# found 0 new sources to stocks/tickers/CCK.csv ...
# found 0 new sources to stocks/tickers/CCL.csv ...
# found 0 new sources to stocks/tickers/CDNS.csv ...
# found 0 new sources to stocks/tickers/CDW.csv ...
# found 0 new sources to stocks/tickers/CEG.csv ...
# found 0 new sources to stocks/tickers/CF.csv ...
# found 0 new sources to stocks/tickers/CFG.csv ...
# found 0 new sources to stocks/tickers/CFLT.csv ...
# found 0 new sources to stocks/tickers/CG.csv ...
# found 0 new sources to stocks/tickers/CHD.csv ...
# found 0 new sources to stocks/tickers/CHDN.csv ...
# found 0 new sources to stocks/tickers/CHRW.csv ...
# found 0 new sources to stocks/tickers/CHTR.csv ...
# found 0 new sources to stocks/tickers/CHWY.csv ...
# found 0 new sources to stocks/tickers/CI.csv ...
# found 0 new sources to stocks/tickers/CIEN.csv ...
# found 0 new sources to stocks/tickers/CINF.csv ...
# found 0 new sources to stocks/tickers/CL.csv ...
# found 0 new sources to stocks/tickers/CLH.csv ...
# found 0 new sources to stocks/tickers/CLX.csv ...
# found 0 new sources to stocks/tickers/CMCSA.csv ...
# found 0 new sources to stocks/tickers/CME.csv ...
# found 0 new sources to stocks/tickers/CMG.csv ...
# found 0 new sources to stocks/tickers/CMI.csv ...
# found 0 new sources to stocks/tickers/CMS.csv ...
# found 0 new sources to stocks/tickers/CNA.csv ...
# found 0 new sources to stocks/tickers/CNC.csv ...
# found 0 new sources to stocks/tickers/CNP.csv ...
# found 0 new sources to stocks/tickers/COF.csv ...
# found 0 new sources to stocks/tickers/COHR.csv ...
# found 0 new sources to stocks/tickers/COIN.csv ...
# found 0 new sources to stocks/tickers/COKE.csv ...
# found 0 new sources to stocks/tickers/COO.csv ...
# found 0 new sources to stocks/tickers/COP.csv ...
# found 0 new sources to stocks/tickers/COR.csv ...
# found 0 new sources to stocks/tickers/COST.csv ...
# found 0 new sources to stocks/tickers/CPAY.csv ...
# found 0 new sources to stocks/tickers/CPB.csv ...
# found 0 new sources to stocks/tickers/CPNG.csv ...
# found 0 new sources to stocks/tickers/CPRT.csv ...
# found 0 new sources to stocks/tickers/CPT.csv ...
# found 0 new sources to stocks/tickers/CQP.csv ...
# found 0 new sources to stocks/tickers/CR.csv ...
# found 0 new sources to stocks/tickers/CRBG.csv ...
# found 0 new sources to stocks/tickers/CRH.csv ...
# found 0 new sources to stocks/tickers/CRL.csv ...
# found 0 new sources to stocks/tickers/CRM.csv ...
# found 0 new sources to stocks/tickers/CRS.csv ...
# found 0 new sources to stocks/tickers/CRWD.csv ...
# found 0 new sources to stocks/tickers/CSCO.csv ...
# found 0 new sources to stocks/tickers/CSGP.csv ...
# found 0 new sources to stocks/tickers/CSL.csv ...
# found 0 new sources to stocks/tickers/CSX.csv ...
# found 0 new sources to stocks/tickers/CTAS.csv ...
# found 0 new sources to stocks/tickers/CTLT.csv ...
# found 0 new sources to stocks/tickers/CTRA.csv ...
# found 0 new sources to stocks/tickers/CTSH.csv ...
# found 0 new sources to stocks/tickers/CTVA.csv ...
# found 0 new sources to stocks/tickers/CUBE.csv ...
# found 0 new sources to stocks/tickers/CVNA.csv ...
# found 0 new sources to stocks/tickers/CVS.csv ...
# found 0 new sources to stocks/tickers/CVX.csv ...
# found 0 new sources to stocks/tickers/CW.csv ...
# found 0 new sources to stocks/tickers/D.csv ...
# found 0 new sources to stocks/tickers/DAL.csv ...
# found 0 new sources to stocks/tickers/DASH.csv ...
# found 0 new sources to stocks/tickers/DAY.csv ...
# found 0 new sources to stocks/tickers/DD.csv ...
# found 0 new sources to stocks/tickers/DDOG.csv ...
# found 0 new sources to stocks/tickers/DE.csv ...
# found 0 new sources to stocks/tickers/DECK.csv ...
# found 0 new sources to stocks/tickers/DELL.csv ...
# found 0 new sources to stocks/tickers/DFS.csv ...
# found 0 new sources to stocks/tickers/DG.csv ...
# found 0 new sources to stocks/tickers/DGX.csv ...
# found 0 new sources to stocks/tickers/DHI.csv ...
# found 0 new sources to stocks/tickers/DHR.csv ...
# found 0 new sources to stocks/tickers/DIS.csv ...
# found 0 new sources to stocks/tickers/DKNG.csv ...
# found 0 new sources to stocks/tickers/DKS.csv ...
# found 0 new sources to stocks/tickers/DLR.csv ...
# found 0 new sources to stocks/tickers/DLTR.csv ...
# found 0 new sources to stocks/tickers/DOC.csv ...
# found 0 new sources to stocks/tickers/DOCU.csv ...
# found 0 new sources to stocks/tickers/DOV.csv ...
# found 0 new sources to stocks/tickers/DOW.csv ...
# found 0 new sources to stocks/tickers/DOX.csv ...
# found 0 new sources to stocks/tickers/DPZ.csv ...
# found 0 new sources to stocks/tickers/DRI.csv ...
# found 0 new sources to stocks/tickers/DT.csv ...
# found 0 new sources to stocks/tickers/DTE.csv ...
# found 0 new sources to stocks/tickers/DTM.csv ...
# found 0 new sources to stocks/tickers/DUK.csv ...
# found 0 new sources to stocks/tickers/DUOL.csv ...
# found 0 new sources to stocks/tickers/DVA.csv ...
# found 0 new sources to stocks/tickers/DVN.csv ...
# found 0 new sources to stocks/tickers/DXCM.csv ...
# found 0 new sources to stocks/tickers/EA.csv ...
# found 0 new sources to stocks/tickers/EBAY.csv ...
# found 0 new sources to stocks/tickers/ECL.csv ...
# found 0 new sources to stocks/tickers/ED.csv ...
# found 0 new sources to stocks/tickers/EDR.csv ...
# found 0 new sources to stocks/tickers/EFX.csv ...
# found 0 new sources to stocks/tickers/EHC.csv ...
# found 0 new sources to stocks/tickers/EIX.csv ...
# found 0 new sources to stocks/tickers/EL.csv ...
# found 0 new sources to stocks/tickers/ELS.csv ...
# found 0 new sources to stocks/tickers/ELV.csv ...
# found 0 new sources to stocks/tickers/EME.csv ...
# found 0 new sources to stocks/tickers/EMN.csv ...
# found 0 new sources to stocks/tickers/EMR.csv ...
# found 0 new sources to stocks/tickers/ENPH.csv ...
# found 0 new sources to stocks/tickers/ENTG.csv ...
# found 0 new sources to stocks/tickers/EOG.csv ...
# found 0 new sources to stocks/tickers/EPAM.csv ...
# found 0 new sources to stocks/tickers/EPD.csv ...
# found 0 new sources to stocks/tickers/EQH.csv ...
# found 0 new sources to stocks/tickers/EQIX.csv ...
# found 0 new sources to stocks/tickers/EQR.csv ...
# found 0 new sources to stocks/tickers/EQT.csv ...
# found 0 new sources to stocks/tickers/ERIE.csv ...
# found 0 new sources to stocks/tickers/ES.csv ...
# found 0 new sources to stocks/tickers/ESS.csv ...
# found 0 new sources to stocks/tickers/ESTC.csv ...
# found 0 new sources to stocks/tickers/ET.csv ...
# found 0 new sources to stocks/tickers/ETR.csv ...
# found 0 new sources to stocks/tickers/EVR.csv ...
# found 0 new sources to stocks/tickers/EVRG.csv ...
# found 0 new sources to stocks/tickers/EW.csv ...
# found 0 new sources to stocks/tickers/EWBC.csv ...
# found 0 new sources to stocks/tickers/EXAS.csv ...
# found 0 new sources to stocks/tickers/EXC.csv ...
# found 0 new sources to stocks/tickers/EXE.csv ...
# found 0 new sources to stocks/tickers/EXEL.csv ...
# found 0 new sources to stocks/tickers/EXP.csv ...
# found 0 new sources to stocks/tickers/EXPD.csv ...
# found 0 new sources to stocks/tickers/EXPE.csv ...
# found 0 new sources to stocks/tickers/EXR.csv ...
# found 0 new sources to stocks/tickers/F.csv ...
# found 0 new sources to stocks/tickers/FANG.csv ...
# found 0 new sources to stocks/tickers/FAST.csv ...
# found 0 new sources to stocks/tickers/FBIN.csv ...
# found 0 new sources to stocks/tickers/FCNCA.csv ...
# found 0 new sources to stocks/tickers/FCX.csv ...
# found 0 new sources to stocks/tickers/FDS.csv ...
# found 0 new sources to stocks/tickers/FDX.csv ...
# found 0 new sources to stocks/tickers/FE.csv ...
# found 0 new sources to stocks/tickers/FERG.csv ...
# found 0 new sources to stocks/tickers/FFIV.csv ...
# found 0 new sources to stocks/tickers/FHN.csv ...
# found 0 new sources to stocks/tickers/FI.csv ...
# found 0 new sources to stocks/tickers/FICO.csv ...
# found 0 new sources to stocks/tickers/FIS.csv ...
# found 0 new sources to stocks/tickers/FITB.csv ...
# found 0 new sources to stocks/tickers/FIX.csv ...
# found 0 new sources to stocks/tickers/FLEX.csv ...
# found 0 new sources to stocks/tickers/FLUT.csv ...
# found 0 new sources to stocks/tickers/FND.csv ...
# found 0 new sources to stocks/tickers/FNF.csv ...
# found 0 new sources to stocks/tickers/FOUR.csv ...
# found 0 new sources to stocks/tickers/FOX.csv ...
# found 0 new sources to stocks/tickers/FOXA.csv ...
# found 0 new sources to stocks/tickers/FSLR.csv ...
# found 0 new sources to stocks/tickers/FTAI.csv ...
# found 0 new sources to stocks/tickers/FTI.csv ...
# found 0 new sources to stocks/tickers/FTNT.csv ...
# found 0 new sources to stocks/tickers/FTV.csv ...
# found 0 new sources to stocks/tickers/FWONA.csv ...
# found 0 new sources to stocks/tickers/FWONK.csv ...
# found 0 new sources to stocks/tickers/GAP.csv ...
# found 0 new sources to stocks/tickers/GD.csv ...
# found 0 new sources to stocks/tickers/GDDY.csv ...
# found 0 new sources to stocks/tickers/GE.csv ...
# found 0 new sources to stocks/tickers/GEHC.csv ...
# found 0 new sources to stocks/tickers/GEN.csv ...
# found 0 new sources to stocks/tickers/GEV.csv ...
# found 0 new sources to stocks/tickers/GFS.csv ...
# found 0 new sources to stocks/tickers/GGG.csv ...
# found 0 new sources to stocks/tickers/GILD.csv ...
# found 0 new sources to stocks/tickers/GIS.csv ...
# found 0 new sources to stocks/tickers/GLPI.csv ...
# found 0 new sources to stocks/tickers/GLW.csv ...
# found 0 new sources to stocks/tickers/GM.csv ...
# found 0 new sources to stocks/tickers/GME.csv ...
# found 0 new sources to stocks/tickers/GMED.csv ...
# found 0 new sources to stocks/tickers/GNRC.csv ...
# found 0 new sources to stocks/tickers/GOOG.csv ...
# found 0 new sources to stocks/tickers/GOOGL.csv ...
# found 0 new sources to stocks/tickers/GPC.csv ...
# found 0 new sources to stocks/tickers/GPN.csv ...
# found 0 new sources to stocks/tickers/GS.csv ...
# found 0 new sources to stocks/tickers/GTLB.csv ...
# found 0 new sources to stocks/tickers/GWRE.csv ...
# found 0 new sources to stocks/tickers/GWW.csv ...
# found 0 new sources to stocks/tickers/H.csv ...
# found 0 new sources to stocks/tickers/HAL.csv ...
# found 0 new sources to stocks/tickers/HBAN.csv ...
# found 0 new sources to stocks/tickers/HCA.csv ...
# found 0 new sources to stocks/tickers/HD.csv ...
# found 0 new sources to stocks/tickers/HEI.csv ...
# found 0 new sources to stocks/tickers/HEI-A.csv ...
# found 0 new sources to stocks/tickers/HES.csv ...
# found 0 new sources to stocks/tickers/HIG.csv ...
# found 0 new sources to stocks/tickers/HLI.csv ...
# found 0 new sources to stocks/tickers/HLNE.csv ...
# found 0 new sources to stocks/tickers/HLT.csv ...
# found 0 new sources to stocks/tickers/HOLX.csv ...
# found 0 new sources to stocks/tickers/HON.csv ...
# found 0 new sources to stocks/tickers/HOOD.csv ...
# found 0 new sources to stocks/tickers/HPE.csv ...
# found 0 new sources to stocks/tickers/HPQ.csv ...
# found 0 new sources to stocks/tickers/HRL.csv ...
# found 0 new sources to stocks/tickers/HST.csv ...
# found 0 new sources to stocks/tickers/HSY.csv ...
# found 0 new sources to stocks/tickers/HUBB.csv ...
# found 0 new sources to stocks/tickers/HUBS.csv ...
# found 0 new sources to stocks/tickers/HUM.csv ...
# found 0 new sources to stocks/tickers/HWM.csv ...
# found 0 new sources to stocks/tickers/IBKR.csv ...
# found 0 new sources to stocks/tickers/IBM.csv ...
# found 0 new sources to stocks/tickers/ICE.csv ...
# found 0 new sources to stocks/tickers/IDXX.csv ...
# found 0 new sources to stocks/tickers/IEX.csv ...
# found 0 new sources to stocks/tickers/IFF.csv ...
# found 0 new sources to stocks/tickers/ILMN.csv ...
# found 0 new sources to stocks/tickers/INCY.csv ...
# found 0 new sources to stocks/tickers/INSM.csv ...
# found 0 new sources to stocks/tickers/INTC.csv ...
# found 0 new sources to stocks/tickers/INTU.csv ...
# found 0 new sources to stocks/tickers/INVH.csv ...
# found 0 new sources to stocks/tickers/IOT.csv ...
# found 0 new sources to stocks/tickers/IP.csv ...
# found 0 new sources to stocks/tickers/IPG.csv ...
# found 0 new sources to stocks/tickers/IQV.csv ...
# found 0 new sources to stocks/tickers/IR.csv ...
# found 0 new sources to stocks/tickers/IRM.csv ...
# found 0 new sources to stocks/tickers/ISRG.csv ...
# found 0 new sources to stocks/tickers/IT.csv ...
# found 0 new sources to stocks/tickers/ITT.csv ...
# found 0 new sources to stocks/tickers/ITW.csv ...
# found 0 new sources to stocks/tickers/J.csv ...
# found 0 new sources to stocks/tickers/JBHT.csv ...
# found 0 new sources to stocks/tickers/JBL.csv ...
# found 0 new sources to stocks/tickers/JEF.csv ...
# found 0 new sources to stocks/tickers/JKHY.csv ...
# found 0 new sources to stocks/tickers/JLL.csv ...
# found 0 new sources to stocks/tickers/JNJ.csv ...
# found 0 new sources to stocks/tickers/JNPR.csv ...
# found 0 new sources to stocks/tickers/JPM.csv ...
# found 0 new sources to stocks/tickers/K.csv ...
# found 0 new sources to stocks/tickers/KDP.csv ...
# found 0 new sources to stocks/tickers/KEY.csv ...
# found 0 new sources to stocks/tickers/KEYS.csv ...
# found 0 new sources to stocks/tickers/KHC.csv ...
# found 0 new sources to stocks/tickers/KIM.csv ...
# found 0 new sources to stocks/tickers/KKR.csv ...
# found 0 new sources to stocks/tickers/KLAC.csv ...
# found 0 new sources to stocks/tickers/KMB.csv ...
# found 0 new sources to stocks/tickers/KMI.csv ...
# found 0 new sources to stocks/tickers/KMX.csv ...
# found 0 new sources to stocks/tickers/KNSL.csv ...
# found 0 new sources to stocks/tickers/KO.csv ...
# found 0 new sources to stocks/tickers/KR.csv ...
# found 0 new sources to stocks/tickers/KVUE.csv ...
# found 0 new sources to stocks/tickers/KVYO.csv ...
# found 0 new sources to stocks/tickers/L.csv ...
# found 0 new sources to stocks/tickers/LAD.csv ...
# found 0 new sources to stocks/tickers/LAMR.csv ...
# found 0 new sources to stocks/tickers/LBRDA.csv ...
# found 0 new sources to stocks/tickers/LBRDK.csv ...
# found 0 new sources to stocks/tickers/LDOS.csv ...
# found 0 new sources to stocks/tickers/LECO.csv ...
# found 0 new sources to stocks/tickers/LEN.csv ...
# found 0 new sources to stocks/tickers/LH.csv ...
# found 0 new sources to stocks/tickers/LHX.csv ...
# found 0 new sources to stocks/tickers/LII.csv ...
# found 0 new sources to stocks/tickers/LINE.csv ...
# found 0 new sources to stocks/tickers/LKQ.csv ...
# found 0 new sources to stocks/tickers/LLY.csv ...
# found 0 new sources to stocks/tickers/LLYVA.csv ...
# found 0 new sources to stocks/tickers/LLYVK.csv ...
# found 0 new sources to stocks/tickers/LMT.csv ...
# found 0 new sources to stocks/tickers/LNG.csv ...
# found 0 new sources to stocks/tickers/LNT.csv ...
# found 0 new sources to stocks/tickers/LOW.csv ...
# found 0 new sources to stocks/tickers/LPLA.csv ...
# found 0 new sources to stocks/tickers/LRCX.csv ...
# found 0 new sources to stocks/tickers/LUV.csv ...
# found 0 new sources to stocks/tickers/LVS.csv ...
# found 0 new sources to stocks/tickers/LW.csv ...
# found 0 new sources to stocks/tickers/LYV.csv ...
# found 0 new sources to stocks/tickers/MA.csv ...
# found 0 new sources to stocks/tickers/MAA.csv ...
# found 0 new sources to stocks/tickers/MANH.csv ...
# found 0 new sources to stocks/tickers/MAR.csv ...
# found 0 new sources to stocks/tickers/MAS.csv ...
# found 0 new sources to stocks/tickers/MCD.csv ...
# found 0 new sources to stocks/tickers/MCHP.csv ...
# found 0 new sources to stocks/tickers/MCK.csv ...
# found 0 new sources to stocks/tickers/MCO.csv ...
# found 0 new sources to stocks/tickers/MDB.csv ...
# found 0 new sources to stocks/tickers/MDLZ.csv ...
# found 0 new sources to stocks/tickers/MEDP.csv ...
# found 0 new sources to stocks/tickers/MELI.csv ...
# found 0 new sources to stocks/tickers/MET.csv ...
# found 0 new sources to stocks/tickers/META.csv ...
# found 0 new sources to stocks/tickers/MGM.csv ...
# found 0 new sources to stocks/tickers/MKC.csv ...
# found 0 new sources to stocks/tickers/MKL.csv ...
# found 0 new sources to stocks/tickers/MLM.csv ...
# found 0 new sources to stocks/tickers/MMC.csv ...
# found 0 new sources to stocks/tickers/MMM.csv ...
# found 0 new sources to stocks/tickers/MNST.csv ...
# found 0 new sources to stocks/tickers/MO.csv ...
# found 0 new sources to stocks/tickers/MOH.csv ...
# found 0 new sources to stocks/tickers/MORN.csv ...
# found 0 new sources to stocks/tickers/MPC.csv ...
# found 0 new sources to stocks/tickers/MPLX.csv ...
# found 0 new sources to stocks/tickers/MPWR.csv ...
# found 0 new sources to stocks/tickers/MRK.csv ...
# found 0 new sources to stocks/tickers/MRNA.csv ...
# <class 'Exception'>
# found 0 new sources to stocks/tickers/MRVL.csv ...
# found 0 new sources to stocks/tickers/MS.csv ...
# found 0 new sources to stocks/tickers/MSCI.csv ...
# found 3 new sources to stocks/tickers/MSFT.csv ...
# found 0 new sources to stocks/tickers/MSI.csv ...
# found 0 new sources to stocks/tickers/MSTR.csv ...
# found 0 new sources to stocks/tickers/MTB.csv ...
# found 0 new sources to stocks/tickers/MTD.csv ...
# found 0 new sources to stocks/tickers/MTSI.csv ...
# found 0 new sources to stocks/tickers/MTZ.csv ...
# found 0 new sources to stocks/tickers/MU.csv ...
# found 0 new sources to stocks/tickers/MUSA.csv ...
# found 0 new sources to stocks/tickers/NBIX.csv ...
# found 0 new sources to stocks/tickers/NCLH.csv ...
# found 0 new sources to stocks/tickers/NDAQ.csv ...
# found 0 new sources to stocks/tickers/NDSN.csv ...
# found 0 new sources to stocks/tickers/NEE.csv ...
# found 0 new sources to stocks/tickers/NEM.csv ...
# found 0 new sources to stocks/tickers/NET.csv ...
# found 0 new sources to stocks/tickers/NFLX.csv ...
# found 0 new sources to stocks/tickers/NI.csv ...
# found 0 new sources to stocks/tickers/NKE.csv ...
# found 0 new sources to stocks/tickers/NLY.csv ...
# found 0 new sources to stocks/tickers/NOC.csv ...
# found 0 new sources to stocks/tickers/NOW.csv ...
# found 0 new sources to stocks/tickers/NRG.csv ...
# found 0 new sources to stocks/tickers/NSC.csv ...
# found 0 new sources to stocks/tickers/NTAP.csv ...
# found 0 new sources to stocks/tickers/NTNX.csv ...
# found 0 new sources to stocks/tickers/NTRA.csv ...
# found 0 new sources to stocks/tickers/NTRS.csv ...
# found 0 new sources to stocks/tickers/NUE.csv ...
# found 2 new sources to stocks/tickers/NVDA.csv ...
# found 0 new sources to stocks/tickers/NVR.csv ...
# found 0 new sources to stocks/tickers/NWS.csv ...
# found 0 new sources to stocks/tickers/NWSA.csv ...
# found 0 new sources to stocks/tickers/O.csv ...
# found 0 new sources to stocks/tickers/OC.csv ...
# found 0 new sources to stocks/tickers/ODFL.csv ...
# found 0 new sources to stocks/tickers/OHI.csv ...
# found 0 new sources to stocks/tickers/OKE.csv ...
# found 0 new sources to stocks/tickers/OKTA.csv ...
# found 0 new sources to stocks/tickers/OMC.csv ...
# found 0 new sources to stocks/tickers/ON.csv ...
# found 0 new sources to stocks/tickers/ORCL.csv ...
# found 0 new sources to stocks/tickers/ORLY.csv ...
# found 0 new sources to stocks/tickers/OTIS.csv ...
# found 0 new sources to stocks/tickers/OVV.csv ...
# found 0 new sources to stocks/tickers/OWL.csv ...
# found 0 new sources to stocks/tickers/OXY.csv ...
# found 0 new sources to stocks/tickers/PAA.csv ...
# found 0 new sources to stocks/tickers/PAG.csv ...
# found 0 new sources to stocks/tickers/PAGP.csv ...
# found 0 new sources to stocks/tickers/PANW.csv ...
# found 0 new sources to stocks/tickers/PAYC.csv ...
# found 0 new sources to stocks/tickers/PAYX.csv ...
# found 0 new sources to stocks/tickers/PCAR.csv ...
# found 0 new sources to stocks/tickers/PCG.csv ...
# found 0 new sources to stocks/tickers/PCOR.csv ...
# found 0 new sources to stocks/tickers/PCTY.csv ...
# found 0 new sources to stocks/tickers/PCVX.csv ...
# found 0 new sources to stocks/tickers/PEG.csv ...
# found 0 new sources to stocks/tickers/PEP.csv ...
# found 0 new sources to stocks/tickers/PFE.csv ...
# found 0 new sources to stocks/tickers/PFG.csv ...
# found 0 new sources to stocks/tickers/PFGC.csv ...
# found 0 new sources to stocks/tickers/PG.csv ...
# found 0 new sources to stocks/tickers/PGR.csv ...
# found 0 new sources to stocks/tickers/PH.csv ...
# found 0 new sources to stocks/tickers/PHM.csv ...
# found 0 new sources to stocks/tickers/PINS.csv ...
# found 0 new sources to stocks/tickers/PKG.csv ...
# found 0 new sources to stocks/tickers/PLD.csv ...
# found 0 new sources to stocks/tickers/PLTR.csv ...
# found 0 new sources to stocks/tickers/PM.csv ...
# found 0 new sources to stocks/tickers/PNC.csv ...
# found 0 new sources to stocks/tickers/PNFP.csv ...
# found 0 new sources to stocks/tickers/PNW.csv ...
# found 0 new sources to stocks/tickers/PODD.csv ...
# found 0 new sources to stocks/tickers/POOL.csv ...
# found 0 new sources to stocks/tickers/PPC.csv ...
# found 0 new sources to stocks/tickers/PPG.csv ...
# found 0 new sources to stocks/tickers/PPL.csv ...
# found 0 new sources to stocks/tickers/PR.csv ...
# found 0 new sources to stocks/tickers/PRI.csv ...
# found 0 new sources to stocks/tickers/PRMB.csv ...
# found 0 new sources to stocks/tickers/PRU.csv ...
# found 0 new sources to stocks/tickers/PSA.csv ...
# found 0 new sources to stocks/tickers/PSN.csv ...
# found 0 new sources to stocks/tickers/PSTG.csv ...
# found 0 new sources to stocks/tickers/PSX.csv ...
# found 0 new sources to stocks/tickers/PTC.csv ...
# found 0 new sources to stocks/tickers/PWR.csv ...
# found 0 new sources to stocks/tickers/PYPL.csv ...
# found 0 new sources to stocks/tickers/QCOM.csv ...
# found 0 new sources to stocks/tickers/RBA.csv ...
# found 0 new sources to stocks/tickers/RBC.csv ...
# found 0 new sources to stocks/tickers/RBLX.csv ...
# found 0 new sources to stocks/tickers/RCL.csv ...
# found 0 new sources to stocks/tickers/RDDT.csv ...
# found 0 new sources to stocks/tickers/REG.csv ...
# found 0 new sources to stocks/tickers/REGN.csv ...
# found 0 new sources to stocks/tickers/RF.csv ...
# found 0 new sources to stocks/tickers/RGA.csv ...
# found 0 new sources to stocks/tickers/RIVN.csv ...
# found 0 new sources to stocks/tickers/RJF.csv ...
# found 0 new sources to stocks/tickers/RKLB.csv ...
# found 0 new sources to stocks/tickers/RKT.csv ...
# found 0 new sources to stocks/tickers/RL.csv ...
# found 0 new sources to stocks/tickers/RMD.csv ...
# found 0 new sources to stocks/tickers/ROK.csv ...
# found 0 new sources to stocks/tickers/ROL.csv ...
# found 0 new sources to stocks/tickers/ROP.csv ...
# found 0 new sources to stocks/tickers/ROST.csv ...
# found 0 new sources to stocks/tickers/RPM.csv ...
# found 0 new sources to stocks/tickers/RPRX.csv ...
# found 0 new sources to stocks/tickers/RRX.csv ...
# found 0 new sources to stocks/tickers/RS.csv ...
# found 0 new sources to stocks/tickers/RSG.csv ...
# found 0 new sources to stocks/tickers/RTX.csv ...
# found 0 new sources to stocks/tickers/RVTY.csv ...
# found 0 new sources to stocks/tickers/RYAN.csv ...
# found 0 new sources to stocks/tickers/SAIA.csv ...
# found 0 new sources to stocks/tickers/SBAC.csv ...
# found 4 new sources to stocks/tickers/SBUX.csv ...
# found 0 new sources to stocks/tickers/SCCO.csv ...
# found 0 new sources to stocks/tickers/SCHW.csv ...
# found 0 new sources to stocks/tickers/SCI.csv ...
# found 0 new sources to stocks/tickers/SEIC.csv ...
# found 0 new sources to stocks/tickers/SF.csv ...
# found 0 new sources to stocks/tickers/SFM.csv ...
# found 0 new sources to stocks/tickers/SHW.csv ...
# found 0 new sources to stocks/tickers/SJM.csv ...
# found 0 new sources to stocks/tickers/SLB.csv ...
# found 0 new sources to stocks/tickers/SMCI.csv ...
# found 0 new sources to stocks/tickers/SMMT.csv ...
# found 0 new sources to stocks/tickers/SN.csv ...
# found 0 new sources to stocks/tickers/SNA.csv ...
# found 0 new sources to stocks/tickers/SNAP.csv ...
# found 1 new sources to stocks/tickers/SNOW.csv ...
# found 0 new sources to stocks/tickers/SNPS.csv ...
# found 0 new sources to stocks/tickers/SNX.csv ...
# found 0 new sources to stocks/tickers/SO.csv ...
# found 0 new sources to stocks/tickers/SOFI.csv ...
# found 0 new sources to stocks/tickers/SOLV.csv ...
# found 0 new sources to stocks/tickers/SPG.csv ...
# found 0 new sources to stocks/tickers/SPGI.csv ...
# found 0 new sources to stocks/tickers/SQ.csv ...
# found 0 new sources to stocks/tickers/SRE.csv ...
# found 0 new sources to stocks/tickers/SRPT.csv ...
# found 0 new sources to stocks/tickers/SSNC.csv ...
# found 0 new sources to stocks/tickers/STLD.csv ...
# found 0 new sources to stocks/tickers/STT.csv ...
# found 0 new sources to stocks/tickers/STX.csv ...
# found 0 new sources to stocks/tickers/STZ.csv ...
# found 0 new sources to stocks/tickers/SUI.csv ...
# found 0 new sources to stocks/tickers/SWK.csv ...
# found 0 new sources to stocks/tickers/SWKS.csv ...
# found 0 new sources to stocks/tickers/SYF.csv ...
# found 0 new sources to stocks/tickers/SYK.csv ...
# found 1 new sources to stocks/tickers/SYM.csv ...
# found 0 new sources to stocks/tickers/SYY.csv ...
# found 1 new sources to stocks/tickers/T.csv ...
# found 0 new sources to stocks/tickers/TAP.csv ...
# found 0 new sources to stocks/tickers/TDG.csv ...
# found 0 new sources to stocks/tickers/TDY.csv ...
# found 0 new sources to stocks/tickers/TEAM.csv ...
# found 0 new sources to stocks/tickers/TECH.csv ...
# found 0 new sources to stocks/tickers/TEM.csv ...
# found 0 new sources to stocks/tickers/TER.csv ...
# found 0 new sources to stocks/tickers/TFC.csv ...
# found 0 new sources to stocks/tickers/TGT.csv ...
# found 0 new sources to stocks/tickers/THC.csv ...
# found 0 new sources to stocks/tickers/TJX.csv ...
# found 0 new sources to stocks/tickers/TKO.csv ...
# found 0 new sources to stocks/tickers/TMO.csv ...
# found 1 new sources to stocks/tickers/TMUS.csv ...
# found 0 new sources to stocks/tickers/TOL.csv ...
# found 0 new sources to stocks/tickers/TOST.csv ...
# found 1 new sources to stocks/tickers/TPG.csv ...
# found 0 new sources to stocks/tickers/TPL.csv ...
# found 0 new sources to stocks/tickers/TPR.csv ...
# found 0 new sources to stocks/tickers/TPX.csv ...
# found 0 new sources to stocks/tickers/TRGP.csv ...
# found 0 new sources to stocks/tickers/TRMB.csv ...
# found 0 new sources to stocks/tickers/TROW.csv ...
# found 0 new sources to stocks/tickers/TRU.csv ...
# found 0 new sources to stocks/tickers/TRV.csv ...
# found 0 new sources to stocks/tickers/TSCO.csv ...
# found 4 new sources to stocks/tickers/TSLA.csv ...
# found 0 new sources to stocks/tickers/TSN.csv ...
# found 0 new sources to stocks/tickers/TTD.csv ...
# found 0 new sources to stocks/tickers/TTEK.csv ...
# found 0 new sources to stocks/tickers/TTWO.csv ...
# found 0 new sources to stocks/tickers/TW.csv ...
# found 0 new sources to stocks/tickers/TWLO.csv ...
# found 0 new sources to stocks/tickers/TXN.csv ...
# found 0 new sources to stocks/tickers/TXRH.csv ...
# found 0 new sources to stocks/tickers/TXT.csv ...
# found 0 new sources to stocks/tickers/TYL.csv ...
# found 0 new sources to stocks/tickers/U.csv ...
# found 0 new sources to stocks/tickers/UAL.csv ...
# found 1 new sources to stocks/tickers/UBER.csv ...
# found 0 new sources to stocks/tickers/UDR.csv ...
# found 0 new sources to stocks/tickers/UHAL.csv ...
# found 0 new sources to stocks/tickers/UHAL-B.csv ...
# found 0 new sources to stocks/tickers/UHS.csv ...
# found 0 new sources to stocks/tickers/UI.csv ...
# found 0 new sources to stocks/tickers/ULS.csv ...
# found 0 new sources to stocks/tickers/ULTA.csv ...
# found 0 new sources to stocks/tickers/UNH.csv ...
# found 0 new sources to stocks/tickers/UNM.csv ...
# found 0 new sources to stocks/tickers/UNP.csv ...
# found 0 new sources to stocks/tickers/UPS.csv ...
# found 0 new sources to stocks/tickers/URI.csv ...
# found 0 new sources to stocks/tickers/USB.csv ...
# found 0 new sources to stocks/tickers/USFD.csv ...
# found 0 new sources to stocks/tickers/UTHR.csv ...
# found 0 new sources to stocks/tickers/UWMC.csv ...
# found 0 new sources to stocks/tickers/V.csv ...
# found 0 new sources to stocks/tickers/VEEV.csv ...
# found 0 new sources to stocks/tickers/VICI.csv ...
# found 0 new sources to stocks/tickers/VLO.csv ...
# found 0 new sources to stocks/tickers/VLTO.csv ...
# found 0 new sources to stocks/tickers/VMC.csv ...
# found 0 new sources to stocks/tickers/VNOM.csv ...
# found 0 new sources to stocks/tickers/VRSK.csv ...
# found 0 new sources to stocks/tickers/VRSN.csv ...
# found 0 new sources to stocks/tickers/VRT.csv ...
# found 0 new sources to stocks/tickers/VRTX.csv ...
# found 0 new sources to stocks/tickers/VST.csv ...
# found 0 new sources to stocks/tickers/VTR.csv ...
# found 0 new sources to stocks/tickers/VTRS.csv ...
# found 1 new sources to stocks/tickers/VZ.csv ...
# found 0 new sources to stocks/tickers/WAB.csv ...
# found 0 new sources to stocks/tickers/WAL.csv ...
# found 0 new sources to stocks/tickers/WAT.csv ...
# found 0 new sources to stocks/tickers/WBD.csv ...
# found 0 new sources to stocks/tickers/WBS.csv ...
# found 0 new sources to stocks/tickers/WCC.csv ...
# found 0 new sources to stocks/tickers/WDAY.csv ...
# found 0 new sources to stocks/tickers/WDC.csv ...
# found 0 new sources to stocks/tickers/WEC.csv ...
# found 0 new sources to stocks/tickers/WELL.csv ...
# found 0 new sources to stocks/tickers/WES.csv ...
# found 0 new sources to stocks/tickers/WFC.csv ...
# found 0 new sources to stocks/tickers/WLK.csv ...
# found 0 new sources to stocks/tickers/WM.csv ...
# found 0 new sources to stocks/tickers/WMB.csv ...
# found 0 new sources to stocks/tickers/WMG.csv ...
# found 0 new sources to stocks/tickers/WMS.csv ...
# found 2 new sources to stocks/tickers/WMT.csv ...
# found 0 new sources to stocks/tickers/WPC.csv ...
# found 0 new sources to stocks/tickers/WRB.csv ...
# found 0 new sources to stocks/tickers/WSM.csv ...
# found 0 new sources to stocks/tickers/WSO.csv ...
# found 0 new sources to stocks/tickers/WST.csv ...
# found 0 new sources to stocks/tickers/WTRG.csv ...
# found 0 new sources to stocks/tickers/WWD.csv ...
# found 0 new sources to stocks/tickers/WY.csv ...
# found 0 new sources to stocks/tickers/WYNN.csv ...
# found 0 new sources to stocks/tickers/XEL.csv ...
# found 2 new sources to stocks/tickers/XOM.csv ...
# found 0 new sources to stocks/tickers/XPO.csv ...
# found 0 new sources to stocks/tickers/XYL.csv ...
# found 0 new sources to stocks/tickers/YUM.csv ...
# found 0 new sources to stocks/tickers/Z.csv ...
# found 0 new sources to stocks/tickers/ZBH.csv ...
# found 0 new sources to stocks/tickers/ZBRA.csv ...
# found 0 new sources to stocks/tickers/ZG.csv ...
# found 0 new sources to stocks/tickers/ZM.csv ...
# found 0 new sources to stocks/tickers/ZS.csv ...
# found 0 new sources to stocks/tickers/ZTS.csv ...
# found 0 new sources to stocks/tickers/CELH.csv ...
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 702    None
# 703    None
# 704    None
# 705    None
# 706    None
# Length: 707, dtype: object

# %%
import pandas as pd 
import psycopg2
from investor_watch.constants import TICKER_PATH, STOCK_LIST_PATH
from investor_watch import db

conn = psycopg2.connect(                   # Connect to an existing database
    dbname="postgres", 
    user="postgres", 
    password="password", 
    host = 'localhost', 
    port = '5432'
)
cur = conn.cursor()                        # Open a cursor to perform database operations

table_schema = '''
CREATE TABLE IF NOT EXISTS stocks (
    ticker VARCHAR(10) PRIMARY KEY,
    company VARCHAR(255) NOT NULL,
    sector VARCHAR(100),
    industry VARCHAR(100),
    country VARCHAR(100),
    price NUMERIC(10, 2) CHECK (price >= 0),
    market_cap NUMERIC(10, 2) CHECK (market_cap >= 0)
);

CREATE TABLE IF NOT EXISTS articles (
    id SERIAL PRIMARY KEY,
    ticker VARCHAR(10) REFERENCES stocks(ticker) ON DELETE CASCADE,
    date TIMESTAMP NOT NULL,
    title VARCHAR(255) NOT NULL,
    link TEXT NOT NULL,
    source VARCHAR(100) NOT NULL,
    UNIQUE (ticker, date, title)                                    
);
'''

cur.execute(table_schema)
# Out:
# Tables initialized successfully
# c:\users\patrick4\documents\projects\investor_watch\investor_watch\constants.py

# %% [markdown]
# Insert csv data into the sql tables

# %%
# stock_list.csv -> sql 
df = pd.read_csv(STOCK_LIST_PATH)

for _, row in df.iterrows():
    try:
        cur.execute("""
            INSERT INTO stocks (ticker, company, sector, industry, country, price, market_cap)
            VALUES (%s, %s, %s, %s, %s, %s, %s)
            ON CONFLICT (ticker) DO NOTHING;
        """, (
            row['Ticker'],
            row['Company'],
            row['Sector'],
            row['Industry'],
            row['Country'],
            float(row['Price']),
            float(row['Market Cap (billions)'])
        ))
    except Exception as e:
        print(f"Error inserting {row['Ticker']}: {e}")

conn.commit()

# %%
# ticker.csv -> sql
import os 
from investor_watch.constants import TICKER_PATH

# Get all ticker files from the tickers directory
ticker_files = [f for f in os.listdir(TICKER_PATH) if f.endswith('.csv')]

# Process each ticker file
for ticker_file in ticker_files:
    ticker = ticker_file.split('.')[0]  # Extract ticker from filename
    file_path = os.path.join(TICKER_PATH, ticker_file)
    
    try:
        df = pd.read_csv(file_path)
        print(f"Processing {ticker} with {len(df)} articles...")
        
        for _, row in df.iterrows():
            cur.execute("""
                INSERT INTO articles (ticker, date, title, link, source)
                VALUES (%s, %s, %s, %s, %s)
                ON CONFLICT (ticker, date, title) DO NOTHING;
            """, (
                ticker,
                pd.to_datetime(row['Date']).to_pydatetime(),
                row['Title'],
                row['Link'],
                row['Source']
            ))
        conn.commit()         
    except Exception as e:
        print(f"Error processing {ticker}: {e}")
        conn.rollback()
# Out:
# Processing A with 4 articles...
# Processing AA with 5 articles...
# Error processing AA: insert or update on table "articles" violates foreign key constraint "articles_ticker_fkey"
# DETAIL:  Key (ticker)=(AA) is not present in table "stocks".
#
# Processing AAON with 0 articles...
# Processing AAPL with 170 articles...
# Processing ABBV with 5 articles...
# Processing ABNB with 13 articles...
# Processing ABT with 3 articles...
# Processing ACI with 8 articles...
# Processing ACM with 0 articles...
# Processing ADBE with 24 articles...
# Processing ADI with 4 articles...
# Processing ADM with 27 articles...
# Processing ADP with 2 articles...
# Processing ADSK with 11 articles...
# Processing AEE with 1 articles...
# Processing AEP with 3 articles...
# Processing AFG with 0 articles...
# Processing AFL with 1 articles...
# Processing AFRM with 8 articles...
# Processing AGR with 1 articles...
# Error processing AGR: insert or update on table "articles" violates foreign key constraint "articles_ticker_fkey"
# DETAIL:  Key (ticker)=(AGR) is not present in table "stocks".
#
# Processing AIG with 7 articles...
# Processing AIT with 0 articles...
# Processing AIZ with 0 articles...
# Processing AJG with 4 articles...
# Processing AKAM with 3 articles...
# Processing ALAB with 1 articles...
# Processing ALB with 2 articles...
# Error processing ALB: insert or update on table "articles" violates foreign key constraint "articles_ticker_fkey"
# DETAIL:  Key (ticker)=(ALB) is not present in table "stocks".
#
# Processing ALGN with 1 articles...
# Processing ALL with 3 articles...
# Processing ALLY with 8 articles...
# Processing ALNY with 1 articles...
# Processing ALSN with 0 articles...
# Processing AMAT with 8 articles...
# Processing AMD with 20 articles...
# Processing AME with 1 articles...
# Processing AMGN with 10 articles...
# Processing AMH with 0 articles...
# Processing AMP with 5 articles...
# Processing AMT with 1 articles...
# Processing AMZN with 75 articles...
# Processing ANET with 2 articles...
# Processing ANSS with 3 articles...
# Processing AOS with 0 articles...
# Processing APD with 9 articles...
# Processing APG with 0 articles...
# Processing APH with 2 articles...
# Processing APO with 2 articles...
# Processing APP with 4 articles...
# Processing AR with 1 articles...
# Processing ARCC with 0 articles...
# Processing ARE with 1 articles...
# Processing ARES with 39 articles...
# Processing ARMK with 1 articles...
# Error processing ARMK: insert or update on table "articles" violates foreign key constraint "articles_ticker_fkey"
# DETAIL:  Key (ticker)=(ARMK) is not present in table "stocks".
#
# Processing ATO with 1 articles...
# Processing ATR with 0 articles...
# Processing AUR with 1 articles...
# Processing AVB with 0 articles...
# Processing AVGO with 31 articles...
# Processing AVTR with 0 articles...
# Processing AVY with 0 articles...
# Processing AWK with 1 articles...
# Processing AXON with 2 articles...
# Processing AXP with 11 articles...
# Processing AYI with 0 articles...
# Processing AZO with 3 articles...
# Processing AZPN with 4 articles...
# Processing BA with 109 articles...
# Processing BAC with 54 articles...
# Processing BAH with 1 articles...
# Processing BALL with 4 articles...
# Processing BAX with 3 articles...
# Processing BBY with 5 articles...
# Processing BDX with 2 articles...
# Processing BEN with 19 articles...
# Processing BEPC with 0 articles...
# Processing BF-A with 7 articles...
# Processing BF-B with 8 articles...
# Processing BG with 17 articles...
# Processing BIIB with 7 articles...
# Processing BJ with 0 articles...
# Processing BK with 4 articles...
# Processing BKNG with 9 articles...
# Processing BKR with 14 articles...
# Processing BLD with 0 articles...
# Processing BLDR with 0 articles...
# Processing BLK with 125 articles...
# Processing BMRN with 0 articles...
# Processing BMY with 0 articles...
# Processing BR with 3 articles...
# Processing BRBR with 0 articles...
# Processing BRK-A with 7 articles...
# Processing BRK-B with 3 articles...
# Processing BRO with 4 articles...
# Processing BSX with 0 articles...
# Processing BSY with 2 articles...
# Processing BURL with 0 articles...
# Processing BWXT with 0 articles...
# Processing BX with 107 articles...
# Processing BXP with 3 articles...
# Processing C with 78 articles...
# Processing CACI with 1 articles...
# Error processing CACI: insert or update on table "articles" violates foreign key constraint "articles_ticker_fkey"
# DETAIL:  Key (ticker)=(CACI) is not present in table "stocks".
#
# Processing CAG with 2 articles...
# Processing CAH with 1 articles...
# Processing CARR with 3 articles...
# Processing CART with 3 articles...
# Processing CASY with 0 articles...
# Processing CAT with 8 articles...
# Processing CAVA with 1 articles...
# Error processing CAVA: insert or update on table "articles" violates foreign key constraint "articles_ticker_fkey"
# DETAIL:  Key (ticker)=(CAVA) is not present in table "stocks".
#
# Processing CBOE with 14 articles...
# Processing CBRE with 4 articles...
# Processing CCI with 10 articles...
# Processing CCK with 0 articles...
# Processing CCL with 3 articles...
# Processing CDNS with 3 articles...
# Processing CDW with 2 articles...
# Processing CEG with 1 articles...
# Processing CELH with 1 articles...
# Error processing CELH: insert or update on table "articles" violates foreign key constraint "articles_ticker_fkey"
# DETAIL:  Key (ticker)=(CELH) is not present in table "stocks".
#
# Processing CF with 8 articles...
# Processing CFG with 3 articles...
# Processing CFLT with 0 articles...
# Processing CG with 63 articles...
# Processing CHD with 3 articles...
# Processing CHDN with 0 articles...
# Processing CHRW with 4 articles...
# Processing CHTR with 14 articles...
# Processing CHWY with 1 articles...
# Processing CI with 12 articles...
# Processing CIEN with 0 articles...
# Processing CINF with 2 articles...
# Processing CL with 3 articles...
# Processing CLH with 0 articles...
# Processing CLX with 2 articles...
# Processing CMCSA with 15 articles...
# Processing CME with 13 articles...
# Processing CMG with 10 articles...
# Processing CMI with 3 articles...
# Processing CMS with 3 articles...
# Processing CNA with 1 articles...
# Processing CNC with 1 articles...
# Processing CNP with 15 articles...
# Processing COF with 16 articles...
# Processing COHR with 1 articles...
# Processing COIN with 24 articles...
# Processing COKE with 0 articles...
# Processing COO with 1 articles...
# Processing COP with 9 articles...
# Processing COR with 1 articles...
# Processing COST with 7 articles...
# Processing CPAY with 1 articles...
# Processing CPB with 2 articles...
# Processing CPNG with 3 articles...
# Processing CPRT with 2 articles...
# Processing CPT with 2 articles...
# Processing CQP with 17 articles...
# Processing CR with 0 articles...
# Processing CRBG with 0 articles...
# Processing CRH with 0 articles...
# Processing CRL with 1 articles...
# Error processing CRL: insert or update on table "articles" violates foreign key constraint "articles_ticker_fkey"
# DETAIL:  Key (ticker)=(CRL) is not present in table "stocks".
#
# Processing CRM with 20 articles...
# Processing CRS with 0 articles...
# Processing CRWD with 11 articles...
# Processing CSCO with 10 articles...
# Processing CSGP with 3 articles...
# Processing CSL with 0 articles...
# Processing CSX with 1 articles...
# Processing CTAS with 0 articles...
# Processing CTLT with 33 articles...
# Error processing CTLT: insert or update on table "articles" violates foreign key constraint "articles_ticker_fkey"
# DETAIL:  Key (ticker)=(CTLT) is not present in table "stocks".
#
# Processing CTRA with 0 articles...
# Processing CTSH with 6 articles...
# Processing CTVA with 9 articles...
# Processing CUBE with 0 articles...
# Processing CVNA with 9 articles...
# Processing CVS with 19 articles...
# Processing CVX with 78 articles...
# Processing CW with 0 articles...
# Processing D with 8 articles...
# Processing DAL with 15 articles...
# Processing DASH with 0 articles...
# Processing DAY with 1 articles...
# Error processing DAY: insert or update on table "articles" violates foreign key constraint "articles_ticker_fkey"
# DETAIL:  Key (ticker)=(DAY) is not present in table "stocks".
#
# Processing DD with 6 articles...
# Processing DDOG with 3 articles...
# Processing DE with 8 articles...
# Processing DECK with 3 articles...
# Processing DELL with 17 articles...
# Processing DFS with 11 articles...
# Processing DG with 2 articles...
# Processing DGX with 0 articles...
# Processing DHI with 5 articles...
# Processing DHR with 0 articles...
# Processing DIS with 33 articles...
# Processing DKNG with 3 articles...
# Processing DKS with 1 articles...
# Processing DLR with 3 articles...
# Processing DLTR with 7 articles...
# Processing DOC with 2 articles...
# Processing DOCU with 0 articles...
# Processing DOV with 0 articles...
# Processing DOW with 0 articles...
# Processing DOX with 0 articles...
# Processing DPZ with 0 articles...
# Processing DRI with 3 articles...
# Processing DT with 0 articles...
# Processing DTE with 3 articles...
# Processing DTM with 0 articles...
# Processing DUK with 2 articles...
# Processing DUOL with 3 articles...
# Processing DVA with 3 articles...
# Processing DVN with 0 articles...
# Processing DXCM with 1 articles...
# Processing EA with 7 articles...
# Processing EBAY with 5 articles...
# Processing ECL with 1 articles...
# Processing ED with 3 articles...
# Processing EDR with 9 articles...
# Processing EFX with 5 articles...
# Processing EHC with 0 articles...
# Processing EIX with 36 articles...
# Processing EL with 5 articles...
# Processing ELS with 0 articles...
# Processing ELV with 2 articles...
# Processing EME with 0 articles...
# Processing EMN with 0 articles...
# Processing EMR with 7 articles...
# Processing ENPH with 2 articles...
# Error processing ENPH: insert or update on table "articles" violates foreign key constraint "articles_ticker_fkey"
# DETAIL:  Key (ticker)=(ENPH) is not present in table "stocks".
#
# Processing ENTG with 3 articles...
# Processing EOG with 6 articles...
# Processing EPAM with 3 articles...
# Processing EPD with 2 articles...
# Processing EQH with 0 articles...
# Processing EQIX with 5 articles...
# Processing EQR with 2 articles...
# Processing EQT with 5 articles...
# Processing ERIE with 1 articles...
# Processing ES with 6 articles...
# Processing ESS with 1 articles...
# Processing ESTC with 0 articles...
# Processing ET with 4 articles...
# Processing ETR with 2 articles...
# Processing EVR with 6 articles...
# Error processing EVR: insert or update on table "articles" violates foreign key constraint "articles_ticker_fkey"
# DETAIL:  Key (ticker)=(EVR) is not present in table "stocks".
#
# Processing EVRG with 0 articles...
# Processing EW with 0 articles...
# Processing EWBC with 1 articles...
# Processing EXAS with 0 articles...
# Processing EXC with 3 articles...
# Processing EXE with 6 articles...
# Processing EXEL with 0 articles...
# Processing EXP with 0 articles...
# Processing EXPD with 3 articles...
# Processing EXPE with 9 articles...
# Processing EXR with 1 articles...
# Processing F with 40 articles...
# Processing FANG with 10 articles...
# Processing FAST with 2 articles...
# Processing FBIN with 0 articles...
# Processing FCNCA with 6 articles...
# Processing FCX with 10 articles...
# Processing FDS with 5 articles...
# Processing FDX with 12 articles...
# Processing FE with 2 articles...
# Processing FERG with 1 articles...
# Processing FFIV with 0 articles...
# Processing FHN with 0 articles...
# Processing FI with 7 articles...
# Processing FICO with 2 articles...
# Processing FIS with 3 articles...
# Processing FITB with 3 articles...
# Processing FIX with 0 articles...
# Processing FLEX with 0 articles...
# Processing FLUT with 7 articles...
# Processing FND with 0 articles...
# Processing FNF with 0 articles...
# Processing FOUR with 2 articles...
# Error processing FOUR: insert or update on table "articles" violates foreign key constraint "articles_ticker_fkey"
# DETAIL:  Key (ticker)=(FOUR) is not present in table "stocks".
#
# Processing FOX with 12 articles...
# Processing FOXA with 12 articles...
# Processing FSLR with 3 articles...
# Processing FTAI with 0 articles...
# Processing FTI with 0 articles...
# Processing FTNT with 3 articles...
# Processing FTV with 0 articles...
# Processing FWONA with 0 articles...
# Processing FWONK with 0 articles...
# Processing GAP with 2 articles...
# Error processing GAP: insert or update on table "articles" violates foreign key constraint "articles_ticker_fkey"
# DETAIL:  Key (ticker)=(GAP) is not present in table "stocks".
#
# Processing GD with 4 articles...
# Processing GDDY with 3 articles...
# Processing GE with 7 articles...
# Processing GEHC with 0 articles...
# Processing GEN with 5 articles...
# Processing GEV with 0 articles...
# Processing GFS with 14 articles...
# Processing GGG with 0 articles...
# Processing GILD with 7 articles...
# Processing GIS with 6 articles...
# Processing GLPI with 0 articles...
# Processing GLW with 0 articles...
# Processing GM with 29 articles...
# Processing GME with 12 articles...
# Processing GMED with 0 articles...
# Processing GNRC with 2 articles...
# Error processing GNRC: insert or update on table "articles" violates foreign key constraint "articles_ticker_fkey"
# DETAIL:  Key (ticker)=(GNRC) is not present in table "stocks".
#
# Processing GOOG with 208 articles...
# Processing GOOGL with 198 articles...
# Processing GPC with 0 articles...
# Processing GPN with 0 articles...
# Processing GS with 29 articles...
# Processing GTLB with 1 articles...
# Error processing GTLB: insert or update on table "articles" violates foreign key constraint "articles_ticker_fkey"
# DETAIL:  Key (ticker)=(GTLB) is not present in table "stocks".
#
# Processing GWRE with 0 articles...
# Processing GWW with 2 articles...
# Processing H with 2 articles...
# Processing HAL with 5 articles...
# Processing HBAN with 3 articles...
# Processing HCA with 5 articles...
# Processing HD with 6 articles...
# Processing HEI-A with 4 articles...
# Processing HEI with 2 articles...
# Processing HES with 15 articles...
# Processing HIG with 2 articles...
# Processing HLI with 8 articles...
# Processing HLNE with 0 articles...
# Processing HLT with 8 articles...
# Processing HOLX with 0 articles...
# Processing HON with 14 articles...
# Processing HOOD with 24 articles...
# Processing HPE with 18 articles...
# Processing HPQ with 13 articles...
# Processing HRL with 2 articles...
# Processing HST with 2 articles...
# Processing HSY with 13 articles...
# Processing HUBB with 1 articles...
# Processing HUBS with 1 articles...
# Processing HUM with 6 articles...
# Processing HWM with 1 articles...
# Processing IBKR with 3 articles...
# Processing IBM with 14 articles...
# Processing ICE with 18 articles...
# Processing IDXX with 1 articles...
# Processing IEX with 1 articles...
# Processing IFF with 1 articles...
# Processing ILMN with 11 articles...
# Processing INCY with 0 articles...
# Processing INSM with 1 articles...
# Processing INTC with 61 articles...
# Processing INTU with 5 articles...
# Processing INVH with 2 articles...
# Processing IOT with 0 articles...
# Processing IP with 3 articles...
# Processing IPG with 5 articles...
# Processing IQV with 1 articles...
# Processing IR with 0 articles...
# Processing IRM with 0 articles...
# Processing ISRG with 0 articles...
# Processing IT with 3 articles...
# Processing ITT with 0 articles...
# Processing ITW with 1 articles...
# Processing J with 0 articles...
# Processing JBHT with 2 articles...
# Processing JBL with 5 articles...
# Processing JEF with 36 articles...
# Processing JKHY with 2 articles...
# Processing JLL with 7 articles...
# Processing JNJ with 13 articles...
# Processing JNPR with 13 articles...
# Processing JPM with 88 articles...
# Processing K with 7 articles...
# Processing KDP with 4 articles...
# Processing KEY with 5 articles...
# Processing KEYS with 3 articles...
# Processing KHC with 9 articles...
# Processing KIM with 2 articles...
# Processing KKR with 95 articles...
# Processing KLAC with 0 articles...
# Processing KMB with 6 articles...
# Processing KMI with 8 articles...
# Processing KMX with 2 articles...
# Processing KNSL with 0 articles...
# Processing KO with 10 articles...
# Processing KR with 12 articles...
# Processing KVUE with 1 articles...
# Processing KVYO with 6 articles...
# Error processing KVYO: insert or update on table "articles" violates foreign key constraint "articles_ticker_fkey"
# DETAIL:  Key (ticker)=(KVYO) is not present in table "stocks".
#
# Processing L with 7 articles...
# Processing LAD with 0 articles...
# Processing LAMR with 0 articles...
# Processing LBRDA with 3 articles...
# Processing LBRDK with 3 articles...
# Processing LDOS with 3 articles...
# Processing LECO with 0 articles...
# Processing LEN with 4 articles...
# Processing LH with 5 articles...
# Processing LHX with 7 articles...
# Processing LII with 3 articles...
# Processing LINE with 3 articles...
# Processing LKQ with 1 articles...
# Processing LLY with 29 articles...
# Processing LLYVA with 0 articles...
# Processing LLYVK with 3 articles...
# Error processing LLYVK: insert or update on table "articles" violates foreign key constraint "articles_ticker_fkey"
# DETAIL:  Key (ticker)=(LLYVK) is not present in table "stocks".
#
# Processing LMT with 14 articles...
# Processing LNG with 17 articles...
# Processing LNT with 3 articles...
# Processing LOW with 3 articles...
# Processing LPLA with 0 articles...
# Processing LRCX with 6 articles...
# Processing LUV with 24 articles...
# Processing LVS with 6 articles...
# Processing LW with 3 articles...
# Error processing LW: insert or update on table "articles" violates foreign key constraint "articles_ticker_fkey"
# DETAIL:  Key (ticker)=(LW) is not present in table "stocks".
#
# Processing LYV with 8 articles...
# Processing MA with 4 articles...
# Processing MAA with 1 articles...
# Processing MANH with 0 articles...
# Processing MAR with 4 articles...
# Processing MAS with 2 articles...
# Processing MCD with 13 articles...
# Processing MCHP with 11 articles...
# Processing MCK with 6 articles...
# Processing MCO with 20 articles...
# Processing MDB with 0 articles...
# Processing MDLZ with 17 articles...
# Processing MEDP with 0 articles...
# Processing MELI with 12 articles...
# Processing MET with 10 articles...
# Processing META with 116 articles...
# Processing MGM with 2 articles...
# Error processing MGM: insert or update on table "articles" violates foreign key constraint "articles_ticker_fkey"
# DETAIL:  Key (ticker)=(MGM) is not present in table "stocks".
#
# Processing MKC with 0 articles...
# Processing MKL with 1 articles...
# Processing MLM with 3 articles...
# Processing MMC with 2 articles...
# Processing MMM with 4 articles...
# Processing MNST with 4 articles...
# Processing MO with 6 articles...
# Processing MOH with 1 articles...
# Processing MORN with 3 articles...
# Processing MPC with 8 articles...
# Processing MPLX with 0 articles...
# Processing MPWR with 2 articles...
# Processing MRK with 2 articles...
# Processing MRNA with 13 articles...
# Processing MRO with 6 articles...
# Error processing MRO: insert or update on table "articles" violates foreign key constraint "articles_ticker_fkey"
# DETAIL:  Key (ticker)=(MRO) is not present in table "stocks".
#
# Processing MRVL with 13 articles...
# Processing MS with 18 articles...
# Processing MSCI with 21 articles...
# Processing MSFT with 103 articles...
# Processing MSI with 4 articles...
# Processing MSTR with 54 articles...
# Processing MTB with 3 articles...
# Processing MTD with 1 articles...
# Processing MTSI with 0 articles...
# Processing MTZ with 0 articles...
# Processing MU with 7 articles...
# Processing MUSA with 0 articles...
# Processing NBIX with 2 articles...
# Processing NCLH with 2 articles...
# Error processing NCLH: insert or update on table "articles" violates foreign key constraint "articles_ticker_fkey"
# DETAIL:  Key (ticker)=(NCLH) is not present in table "stocks".
#
# Processing NDAQ with 21 articles...
# Processing NDSN with 1 articles...
# Processing NEE with 1 articles...
# Processing NEM with 19 articles...
# Processing NET with 5 articles...
# Processing NFLX with 31 articles...
# Processing NI with 1 articles...
# Processing NKE with 12 articles...
# Processing NLY with 0 articles...
# Processing NOC with 3 articles...
# Processing NOW with 9 articles...
# Processing NRG with 2 articles...
# Processing NSC with 6 articles...
# Processing NTAP with 4 articles...
# Processing NTNX with 1 articles...
# Processing NTRA with 0 articles...
# Processing NTRS with 4 articles...
# Processing NUE with 8 articles...
# Processing NVDA with 205 articles...
# Processing NVR with 2 articles...
# Processing NWS with 16 articles...
# Processing NWSA with 15 articles...
# Processing O with 0 articles...
# Processing OC with 0 articles...
# Processing ODFL with 0 articles...
# Processing OHI with 0 articles...
# Processing OKE with 4 articles...
# Processing OKTA with 0 articles...
# Processing OMC with 0 articles...
# Processing ON with 5 articles...
# Processing ORCL with 32 articles...
# Processing ORLY with 1 articles...
# Processing OTIS with 4 articles...
# Processing OVV with 1 articles...
# Processing OWL with 11 articles...
# Processing OXY with 8 articles...
# Processing PAA with 2 articles...
# Processing PAG with 0 articles...
# Processing PAGP with 0 articles...
# Processing PANW with 6 articles...
# Processing PAYC with 2 articles...
# Processing PAYX with 3 articles...
# Processing PCAR with 1 articles...
# Processing PCG with 15 articles...
# Processing PCOR with 0 articles...
# Processing PCTY with 0 articles...
# Processing PCVX with 1 articles...
# Error processing PCVX: insert or update on table "articles" violates foreign key constraint "articles_ticker_fkey"
# DETAIL:  Key (ticker)=(PCVX) is not present in table "stocks".
#
# Processing PEG with 1 articles...
# Processing PEP with 13 articles...
# Processing PFE with 20 articles...
# Processing PFG with 2 articles...
# Processing PFGC with 0 articles...
# Processing PG with 14 articles...
# Processing PGR with 1 articles...
# Processing PH with 0 articles...
# Processing PHM with 3 articles...
# Processing PINS with 7 articles...
# Processing PKG with 3 articles...
# Processing PLD with 2 articles...
# Processing PLTR with 10 articles...
# Processing PM with 10 articles...
# Processing PNC with 8 articles...
# Processing PNFP with 0 articles...
# Processing PNW with 2 articles...
# Processing PODD with 2 articles...
# Processing POOL with 3 articles...
# Processing PPC with 3 articles...
# Processing PPG with 3 articles...
# Processing PPL with 4 articles...
# Processing PR with 0 articles...
# Processing PRI with 0 articles...
# Processing PRMB with 0 articles...
# Processing PRU with 13 articles...
# Processing PSA with 2 articles...
# Processing PSN with 0 articles...
# Processing PSTG with 0 articles...
# Processing PSX with 22 articles...
# Processing PTC with 0 articles...
# Processing PWR with 1 articles...
# Processing PYPL with 12 articles...
# Processing QCOM with 32 articles...
# Processing RBA with 4 articles...
# Processing RBC with 1 articles...
# Processing RBLX with 13 articles...
# Processing RCL with 7 articles...
# Processing RDDT with 24 articles...
# Processing REG with 3 articles...
# Processing REGN with 4 articles...
# Processing RF with 2 articles...
# Processing RGA with 0 articles...
# Processing RIVN with 19 articles...
# Processing RJF with 7 articles...
# Processing RKLB with 0 articles...
# Processing RKT with 3 articles...
# Processing RL with 0 articles...
# Processing RMD with 1 articles...
# Processing ROK with 2 articles...
# Processing ROL with 1 articles...
# Processing ROP with 4 articles...
# Processing ROST with 2 articles...
# Processing RPM with 0 articles...
# Processing RPRX with 0 articles...
# Processing RRX with 0 articles...
# Processing RS with 0 articles...
# Processing RSG with 0 articles...
# Processing RTX with 4 articles...
# Processing RVTY with 2 articles...
# Processing RYAN with 0 articles...
# Processing SAIA with 0 articles...
# Processing SBAC with 3 articles...
# Processing SBUX with 57 articles...
# Processing SCCO with 4 articles...
# Processing SCHW with 19 articles...
# Processing SCI with 1 articles...
# Processing SEIC with 2 articles...
# Error processing SEIC: insert or update on table "articles" violates foreign key constraint "articles_ticker_fkey"
# DETAIL:  Key (ticker)=(SEIC) is not present in table "stocks".
#
# Processing SF with 1 articles...
# Processing SFM with 1 articles...
# Processing SHW with 3 articles...
# Processing SJM with 7 articles...
# Processing SLB with 0 articles...
# Processing SMCI with 23 articles...
# Processing SMMT with 1 articles...
# Processing SN with 0 articles...
# Processing SNA with 2 articles...
# Processing SNAP with 20 articles...
# Processing SNOW with 10 articles...
# Processing SNPS with 16 articles...
# Processing SNX with 0 articles...
# Processing SO with 2 articles...
# Processing SOFI with 3 articles...
# Processing SOLV with 0 articles...
# Processing SPG with 4 articles...
# Processing SPGI with 11 articles...
# Processing SQ with 0 articles...
# Processing SRE with 9 articles...
# Processing SRPT with 1 articles...
# Error processing SRPT: insert or update on table "articles" violates foreign key constraint "articles_ticker_fkey"
# DETAIL:  Key (ticker)=(SRPT) is not present in table "stocks".
#
# Processing SSNC with 0 articles...
# Processing STLD with 5 articles...
# Processing STT with 15 articles...
# Processing STX with 3 articles...
# Processing STZ with 5 articles...
# Processing SUI with 1 articles...
# Processing SWK with 0 articles...
# Processing SWKS with 3 articles...
# Processing SYF with 0 articles...
# Processing SYK with 0 articles...
# Processing SYM with 5 articles...
# Processing SYY with 3 articles...
# Processing T with 25 articles...
# Processing TAP with 0 articles...
# Processing TDG with 1 articles...
# Processing TDY with 1 articles...
# Processing TEAM with 2 articles...
# Processing TECH with 1 articles...
# Processing TEM with 1 articles...
# Error processing TEM: insert or update on table "articles" violates foreign key constraint "articles_ticker_fkey"
# DETAIL:  Key (ticker)=(TEM) is not present in table "stocks".
#
# Processing TER with 3 articles...
# Processing TFC with 4 articles...
# Processing TGT with 13 articles...
# Processing THC with 1 articles...
# Processing TJX with 3 articles...
# Processing TKO with 0 articles...
# Processing TMO with 6 articles...
# Processing TMUS with 14 articles...
# Processing TOL with 1 articles...
# Processing TOST with 0 articles...
# Processing TPG with 11 articles...
# Processing TPL with 0 articles...
# Processing TPR with 13 articles...
# Processing TPX with 5 articles...
# Error processing TPX: insert or update on table "articles" violates foreign key constraint "articles_ticker_fkey"
# DETAIL:  Key (ticker)=(TPX) is not present in table "stocks".
#
# Processing TRGP with 3 articles...
# Processing TRMB with 3 articles...
# Processing TROW with 8 articles...
# Processing TRU with 2 articles...
# Processing TRV with 0 articles...
# Processing TSCO with 1 articles...
# Processing TSLA with 163 articles...
# Processing TSN with 14 articles...
# Processing TTD with 0 articles...
# Processing TTEK with 0 articles...
# Processing TTWO with 3 articles...
# Processing TW with 8 articles...
# Processing TWLO with 0 articles...
# Processing TXN with 8 articles...
# Processing TXRH with 0 articles...
# Processing TXT with 5 articles...
# Processing TYL with 3 articles...
# Processing U with 2 articles...
# Error processing U: insert or update on table "articles" violates foreign key constraint "articles_ticker_fkey"
# DETAIL:  Key (ticker)=(U) is not present in table "stocks".
#
# Processing UAL with 13 articles...
# Processing UBER with 44 articles...
# Processing UDR with 0 articles...
# Processing UHAL-B with 0 articles...
# Processing UHAL with 0 articles...
# Processing UHS with 1 articles...
# Processing UI with 0 articles...
# Processing ULS with 5 articles...
# Processing ULTA with 2 articles...
# Processing UNH with 52 articles...
# Processing UNM with 0 articles...
# Processing UNP with 13 articles...
# Processing UPS with 12 articles...
# Processing URI with 5 articles...
# Processing USB with 5 articles...
# Processing USFD with 0 articles...
# Processing UTHR with 1 articles...
# Processing UWMC with 0 articles...
# Processing V with 0 articles...
# Processing VEEV with 1 articles...
# Processing VICI with 0 articles...
# Processing VLO with 16 articles...
# Processing VLTO with 0 articles...
# Processing VMC with 3 articles...
# Processing VNOM with 0 articles...
# Processing VRSK with 2 articles...
# Processing VRSN with 4 articles...
# Processing VRT with 0 articles...
# Processing VRTX with 2 articles...
# Processing VST with 5 articles...
# Processing VTR with 1 articles...
# Processing VTRS with 3 articles...
# Processing VZ with 20 articles...
# Processing WAB with 0 articles...
# Processing WAL with 1 articles...
# Error processing WAL: insert or update on table "articles" violates foreign key constraint "articles_ticker_fkey"
# DETAIL:  Key (ticker)=(WAL) is not present in table "stocks".
#
# Processing WAT with 4 articles...
# Processing WBD with 0 articles...
# Processing WBS with 3 articles...
# Error processing WBS: insert or update on table "articles" violates foreign key constraint "articles_ticker_fkey"
# DETAIL:  Key (ticker)=(WBS) is not present in table "stocks".
#
# Processing WCC with 0 articles...
# Processing WDAY with 7 articles...
# Processing WDC with 7 articles...
# Processing WEC with 2 articles...
# Processing WELL with 2 articles...
# Processing WES with 0 articles...
# Processing WFC with 28 articles...
# Processing WLK with 0 articles...
# Processing WM with 1 articles...
# Processing WMB with 9 articles...
# Processing WMG with 8 articles...
# Processing WMS with 0 articles...
# Processing WMT with 43 articles...
# Processing WPC with 0 articles...
# Processing WRB with 0 articles...
# Processing WSM with 2 articles...
# Processing WSO with 0 articles...
# Processing WST with 2 articles...
# Processing WTRG with 0 articles...
# Processing WWD with 0 articles...
# Processing WY with 2 articles...
# Processing WYNN with 3 articles...
# Error processing WYNN: insert or update on table "articles" violates foreign key constraint "articles_ticker_fkey"
# DETAIL:  Key (ticker)=(WYNN) is not present in table "stocks".
#
# Processing XEL with 7 articles...
# Processing XOM with 60 articles...
# Processing XPO with 3 articles...
# Processing XYL with 2 articles...
# Processing YUM with 4 articles...
# Processing Z with 3 articles...
# Processing ZBH with 4 articles...
# Processing ZBRA with 3 articles...
# Processing ZG with 3 articles...
# Processing ZM with 8 articles...
# Processing ZS with 5 articles...
# Processing ZTS with 0 articles...

# %% [markdown]
# This notebook enriches `stock` news sources with price movement (price change during date of publish), and search hits. (how 'popular' a news article was)

# %%
import requests 
from datetime import timedelta, datetime
import pandas as pd
import yfinance as yf 
import requests
from investor_watch.constants import TICKER_PATH, GOOGLE_API_KEY, SEARCH_ENGINE_ID

# pd.set_option('display.max_rows', None)  # Display all rows

# pd.set_option('display.max_columns', None)  # Display all columns
stock = 'AAPL'
append_mode = False

file = f'{TICKER_PATH}/{stock}.csv'
news_df = pd.read_csv(file, parse_dates=['Date'])
snapshot = news_df.copy()

news_df.head(5)
# Out:
# c:\users\patrick4\documents\projects\investor_watch c:\users\patrick4\documents\projects\investor_watch\stocks\tickers c:\users\patrick4\documents\projects\investor_watch\stocks\stocks.csv
#                  Date                                              Title  \
# 0 2024-11-20 19:20:00  Indonesia to Assess $100 Million Apple Bid to ...
# 1 2024-11-21 23:00:00  Western Australia on Track for Unexpectedly La...
# 2 2024-11-21 16:00:00  Apple Readies More Conversational Siri in Bid ...
# 3 2024-11-21 04:49:00  Apple Rival Oppo Bets on Markets Beyond China ...
# 4 2024-11-22 08:30:00  Apple, Google Risk UK Probe Over Mobile Browse...
#
#                                                 Link     Source  % Change  \
# 0  https://finance.yahoo.com/news/indonesia-asses...  Bloomberg      0.32
# 1  https://finance.yahoo.com/news/western-austral...  Bloomberg     -0.21
# 2  https://finance.yahoo.com/news/apple-readies-m...  Bloomberg     -0.21
# 3  https://finance.yahoo.com/news/apple-rival-opp...  Bloomberg     -0.21
# 4  https://finance.yahoo.com/news/apple-google-ri...  Bloomberg      0.59
#
#    hits
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN

# %% [markdown]
# Populate `news_df` with price changes

# %%
# calculate intraday return in yfinance
def get_stock_quotes(stock, oldest_date): 
    data = yf.download(stock, period = 'max', start = oldest_date - timedelta(weeks = 1))       # news from [oldest_date, today]
    data.columns = data.columns.droplevel(1)                             # drop the multi-level column index
    data.columns.name = None 

    data['Prev Close'] = data['Close'].shift(1)     # get previous close by shifting it down by 1
    data['% Change'] = ((data['Close'] - data['Prev Close']) / data['Prev Close'])  * 100
    data['% Change'] = data['% Change'].round(2)
    data.sort_values('% Change', ascending = False, inplace = True)
    return data

quotes = get_stock_quotes(stock, news_df['Date'].min())               # largest % price changes 

def lookup_date(timestamp):
    '''Looks up the price movement on a given date and populates news df'''
    try:
        return quotes.loc[str(timestamp.date()), '% Change']
    except KeyError:
        return None     # print(f'No price movement data for {timestamp.date()}')

news_df['% Change'] = news_df['Date'].apply(lookup_date)         

news_df.head(5)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Date                                              Title  \
# 0 2024-11-20 19:20:00  Indonesia to Assess $100 Million Apple Bid to ...
# 1 2024-11-21 23:00:00  Western Australia on Track for Unexpectedly La...
# 2 2024-11-21 16:00:00  Apple Readies More Conversational Siri in Bid ...
# 3 2024-11-21 04:49:00  Apple Rival Oppo Bets on Markets Beyond China ...
# 4 2024-11-22 08:30:00  Apple, Google Risk UK Probe Over Mobile Browse...
#
#                                                 Link     Source  % Change  \
# 0  https://finance.yahoo.com/news/indonesia-asses...  Bloomberg      0.32
# 1  https://finance.yahoo.com/news/western-austral...  Bloomberg     -0.21
# 2  https://finance.yahoo.com/news/apple-readies-m...  Bloomberg     -0.21
# 3  https://finance.yahoo.com/news/apple-rival-opp...  Bloomberg     -0.21
# 4  https://finance.yahoo.com/news/apple-google-ri...  Bloomberg      0.59
#
#    hits
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN

# %% [markdown]
# Populate `news_df` with search hits

# %%
def get_google_results(query):      # using google Custom Search JSON API
    params = {
        'q': f'"{query}"',
        'key': GOOGLE_API_KEY, 
        'cx': SEARCH_ENGINE_ID,         
    }

    try: 
        response = requests.get('https://www.googleapis.com/customsearch/v1', params = params).json() 
        if 'totalResults' not in response['queries']['request'][0]: return 0 
        num_results = int(response['queries']['request'][0]['totalResults'])
        print(query, num_results)
        return num_results
    
    except Exception as e:
        print(response)
        raise e

    
'''
Mines the top N days with the highest price change for news catalysts
'''
n = 3          # set this to a low number because of google api limits :)
largest_price_changes = news_df['% Change'].sort_values(key=abs, ascending=False).drop_duplicates().head(n)
largest_price_changes
news_df.loc[news_df['% Change'].isin(largest_price_changes), 'hits'] = news_df.loc[news_df['% Change'].isin(largest_price_changes), 'Title'].apply(get_google_results)

news_df[news_df['hits'] > 0]
# Out:
# {'error': {'code': 429, 'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:630353971842'.", 'errors': [{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:630353971842'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}], 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.ErrorInfo', 'reason': 'RATE_LIMIT_EXCEEDED', 'domain': 'googleapis.com', 'metadata': {'consumer': 'projects/630353971842', 'quota_limit': 'DefaultPerDayPerProject', 'quota_location': 'global', 'quota_metric': 'customsearch.googleapis.com/requests', 'service': 'customsearch.googleapis.com', 'quota_limit_value': '100'}}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Request a higher quota limit.', 'url': 'https://cloud.google.com/docs/quotas/help/request_increase'}]}]}}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[73], line 26
#      24 largest_price_changes = news_df['% Change'].sort_values(key=abs, ascending=False).drop_duplicates().head(n)
#      25 largest_price_changes
# ---> 26 news_df.loc[news_df['% Change'].isin(largest_price_changes), 'hits'] = news_df.loc[news_df['% Change'].isin(largest_price_changes), 'Title'].apply(get_google_results)
#      28 news_df[news_df['hits'] > 0]
#
# File c:\Users\patrick4\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File c:\Users\patrick4\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\patrick4\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\patrick4\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\patrick4\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[73], line 17, in get_google_results(query)
#      15 except Exception as e:
#      16     print(response)
# ---> 17     raise e
#
# Cell In[73], line 10, in get_google_results(query)
#       8 try:
#       9     response = requests.get('https://www.googleapis.com/customsearch/v1', params = params).json()
# ---> 10     if 'totalResults' not in response['queries']['request'][0]: return 0
#      11     num_results = int(response['queries']['request'][0]['totalResults'])
#      12     print(query, num_results)
#
# KeyError: 'queries'

# %%
news_df
# Out:
#                    Date                                              Title  \
# 0   2024-11-20 19:20:00  Indonesia to Assess $100 Million Apple Bid to ...
# 1   2024-11-21 23:00:00  Western Australia on Track for Unexpectedly La...
# 2   2024-11-21 16:00:00  Apple Readies More Conversational Siri in Bid ...
# 3   2024-11-21 04:49:00  Apple Rival Oppo Bets on Markets Beyond China ...
# 4   2024-11-22 08:30:00  Apple, Google Risk UK Probe Over Mobile Browse...
# 5   2024-11-22 06:45:00  UK should use new powers to probe Apple-Google...
# 6   2024-11-24 16:53:00  India Rejects Apples Request to Pause Antitrus...
# 7   2024-11-24 10:01:00  Indian regulator rejects Apple request to put ...
# 8   2024-11-25 08:34:00  Apples Cook Joins CEO Summit with Chinese Prem...
# 9   2024-11-25 06:50:00  Indonesia says Apple's $100 million investment...
# 10  2024-11-30 06:47:00  Irish Vote Close as Exit Poll Shows Harris, Si...
# 11  2024-12-02 13:00:00  Apple accused of silencing workers, spying on ...
# 12  2024-12-03 05:01:00  Indonesia expects $1 billion investment commit...
# 13  2024-12-03 10:26:00  Indonesia Says Apple to Offer $1 Billion to Li...
# 14  2024-12-04 10:15:00  Apple facing hurdles in adapting Baidu AI mode...
# 15  2024-12-04 13:36:00  Trump Taps Vance Aide Gail Slater as Top DOJ A...
# 16  2024-12-05 02:49:00  IPhone Maker Hon Hai Posts 3% Sales Growth Aft...
# 17  2024-12-06 12:52:00  Apple plans three-year modem rollout to compet...
# 18  2024-12-06 16:56:00  Apple Plans Three-Year Modem Rollout in Bid to...
# 19  2024-12-09 09:03:00  Trump Is on Collision Course With EU Over Big ...
# 20  2024-12-10 11:56:00  Apple Shares Are on a Tear Despite Sluggish Gr...
# 21  2024-12-10 14:27:00  Apples Next Ultra Smartwatch Will Be Able to S...
# 22  2024-12-10 14:57:00  Apple to bring satellite communications to sma...
# 23  2024-12-11 08:03:00  Apple adds ChatGPT to iPhone in latest iOS update
# 24  2024-12-11 08:47:00  UK PM Starmer to meet Apple CEO to discuss inv...
# 25  2024-12-12 11:00:00  Google Unveils Mixed-Reality Headset With Sams...
# 26  2024-12-12 14:47:00  Apple nears switch to in-house Bluetooth and W...
# 27  2024-12-12 18:31:00  Broadcom Shares Jump After Chipmaker Predicts ...
# 28  2024-12-12 19:35:00  Xiaomis 103% Rally Puts EV Dark Horse on Brink...
# 29  2024-12-13 04:35:00  Xiaomis 101% Rally Puts EV Dark Horse on Brink...
# 30  2024-12-13 16:23:00  Broadcom Valuation Soars Past $1 Trillion on A...
# 31  2024-12-13 18:24:00    Apple CEO Tim Cook to meet with Trump on Friday
# 32  2024-12-16 09:04:00  Tim Cook and Rebecca Ferguson announce new 'Si...
# 33  2024-12-17 12:05:00  Exclusive-Congo files criminal complaints agai...
# 34  2024-12-17 16:32:00  Arm, Qualcomm lawyers grill ex-Apple exec in c...
# 35  2024-12-18 21:04:00  EU Escalates Pressure on Apple to Open Up Feat...
# 36  2024-12-18 23:39:00  Apple in talks with Tencent, ByteDance to roll...
# 37  2024-12-21 20:00:00  Apples $1 Billion Investment May Be Fleeting W...
# 38  2024-12-23 08:42:00  Apple approaches $4 trillion valuation as inve...
# 39  2024-12-23 14:08:00  Tesla, Meta and Broadcom Weights Shrink in Nas...
# 40  2024-12-24 10:20:00  Apple seeks to defend Google's billion-dollar ...
# 41  2025-01-02 04:14:00  Nvidia's market value gets $2 trillion boost t...
# 42  2025-01-02 10:12:00  Apple to pay $95 million to settle Siri privac...
# 43  2025-01-02 12:57:00  Apple offers iPhone discounts in China as comp...
# 44  2025-01-03 02:00:00  Chipmaker Imaginations Owners Tap Lazard to Se...
# 45  2025-01-03 02:15:00  Apple's China troubles mount as foreign phone ...
# 46  2025-01-05 21:39:00  Nvidia-Partner Hon Hais Shares Climb After AI ...
# 47  2025-01-06 11:37:00  TikTok Ban Thrusts Apple, Google Into US-China...
# 48  2025-01-06 14:45:00  Dell Unveils Apple-Like Rebrand in Bid to Make...
# 49  2025-01-07 10:07:00  Apple Faces Tough January as China Weakness, T...
# 50  2025-01-07 12:52:00  Indonesia, Apple discuss investment proposal l...
# 51  2025-01-08 22:00:00  Apple clarifies Siri privacy stance after $95 ...
# 52  2025-01-09 14:01:00  Microsoft, Google, Adobe Give $1 Million Each ...
# 53  2025-01-10 10:21:00  TSMC Sales Beat Estimates in Boost for AIs Out...
# 54  2025-01-10 15:54:00  Supreme Court Signals Its Likely to Uphold Tik...
# 55  2025-01-10 17:16:00  Apple CEO Pay Rises 18%; Company Opposes Anti-...
# 56  2025-01-11 20:31:00  Apple's board recommends shareholders vote aga...
# 57  2025-01-13 07:00:00  Apple fights $1.8 billion App Store lawsuit in...
# 58  2025-01-13 08:03:00  Exclusive: Tech supplier Arm plans to hike pri...
# 59  2025-01-13 10:12:00  Apple's new fees for app developers under fres...
# 60  2025-01-13 12:33:00  iPhone Sales Drop 5% in Holiday Quarter After ...
# 61  2025-01-13 12:41:00  Apple, Samsung smartphone shipments fall in fo...
# 62  2025-01-16 06:18:00  How a TikTok ban would work - and why user wor...
# 63  2025-01-16 10:07:00  TSMCs Upbeat Outlook Fuels Hopes for 2025 AI S...
# 64  2025-01-17 09:39:00  Microsofts Stock Revival Hinges on Showing Gro...
# 65  2025-01-17 12:49:00  TikToks Future Hinges on Trump After Supreme C...
# 66  2025-01-17 22:27:00  TikToks Fate Rests on Trump After Supreme Cour...
# 67  2025-01-20 23:55:00  Apples iPhone Sales in China Plunged 18% in Ho...
# 68  2025-01-21 10:08:00  TikTok app unavailable on Apple, Google stores...
# 69  2025-01-21 15:01:00  Meta Plans Oakley-Branded Glasses, Explores Wa...
# 70  2025-01-21 16:22:00  Apple Loses Top-Stock Crown as Analysts Downgr...
# 71  2025-01-21 22:00:00  Swedish Spam Blocker Truecaller Takes on AI Vo...
# 72  2025-01-22 06:21:00  Nasdaq 100s Historic Bull Run Has Further to G...
# 73  2025-01-22 12:14:00  Indonesia close to deal to lift Indonesian iPh...
# 74  2025-01-22 12:14:00  Indonesia close to deal to lift Apple iPhone 1...
# 75  2025-01-22 13:00:00  Samsung Set to Enter AR Glasses Market in Race...
# 76  2025-01-22 20:54:00  Samsung to Beat Apple to Ultrathin Phone With ...
# 77  2025-01-22 23:48:00  Exclusive-India watchdog faults probe of Foxco...
# 78  2025-01-23 04:37:00  India sends notices to Uber, Ola over pricing ...
# 79  2025-01-23 05:11:00  UK to investigate Apple and Google's mobile ec...
# 80  2025-01-23 05:55:00  Apple and Google Hit by UK Probe Into Mobile D...
# 81  2025-01-23 09:39:00  Oracle Takes Run at Clouds Big Three With Trum...
# 82  2025-01-23 12:17:00  Indonesia says near deal to end ban on Apple i...
# 83  2025-01-23 13:00:00  Epic Games Ramps Up Apple, Google Fight With T...
# 84  2025-01-23 13:10:00  Perplexity debuts AI assistant on Android to c...
# 85  2025-01-23 13:35:00  Epic Games kicks off plan to add third-party g...
# 86  2025-01-24 11:52:00  Apple Enlists Veteran Software Executive to He...
# 87  2025-01-24 12:02:00  Oracle, Apple, Google Diverge on Whether to Ke...
# 88  2025-01-24 16:15:00  Apple Tests Key Technical Level in Worst Start...
# 89  2025-01-27 05:00:00  Wall Street Options Pros Play It Cool Before K...
# 90  2025-01-27 06:03:00                          Morning Bid: AI, aye, aye
# 91  2025-01-28 22:29:00  Apple's iPhones to support Starlink direct-to-...
# 92  2025-01-29 05:58:00  Apple's sales likely hurt by AI delays, Chines...
# 93  2025-01-29 06:02:00  Apple and SpaceX Link Up to Support Starlink S...
# 94  2025-01-29 08:38:00  DeepSeek cannot be accessed on Apple and Googl...
# 95  2025-01-29 08:38:00  DeepSeek app unavailable in Apple and Google a...
# 96  2025-01-29 09:33:00  Apple Gets Another Downgrade on iPhone Risk Ah...
# 97  2025-01-30 12:55:00  RBA Ramps Up Scrutiny on Australian Pension Fu...
# 98  2025-01-30 13:50:00  Apples Flagging AI Hopes Get Revival From Deep...
# 99  2025-01-30 16:32:00  Apple profit tops Wall Street target even as i...
# 100 2025-01-30 19:31:00  Apple Forecast Cheers Investors After Mixed Ho...
# 101 2025-01-31 05:29:00  Apple lifts US stock index futures as crucial ...
# 102 2025-01-31 11:39:00  Apple Forecast Reassures Investors After Mixed...
# 103 2025-01-31 14:25:00  Apple Scraps Work on Mac-Connected Augmented R...
# 104 2025-02-03 19:36:00  Apple raises concern over first porn app on iP...
# 105 2025-02-04 11:59:00  Apple Blasts EU Laws After First Porn App Come...
# 106 2025-02-04 12:11:00  Apple Debuts Invites App, Care+ Changes in Sub...
# 107 2025-02-05 04:19:00  China considers probe into Apple's App Store f...
# 108 2025-02-06 10:00:00  YouTube Is Buying TikTok Ads to Lure Creators ...
# 109 2025-02-06 10:00:00  Apples China Focus Thrusts It Into Center of G...
# 110 2025-02-06 10:16:00  Qualcomm Falls on Concerns About Slowing Smart...
# 111 2025-02-06 18:16:00  Apples Long-Awaited Overhaul of iPhone SE Near...
# 112 2025-02-07 12:41:00  Apple Ordered by UK to Build Backdoor to Acces...
# 113 2025-02-07 16:44:00  Apples Dilemma in UK Over Encryption Alarms Pr...
#
#                                                   Link     Source  % Change  \
# 0    https://finance.yahoo.com/news/indonesia-asses...  Bloomberg      0.32
# 1    https://finance.yahoo.com/news/western-austral...  Bloomberg     -0.21
# 2    https://finance.yahoo.com/news/apple-readies-m...  Bloomberg     -0.21
# 3    https://finance.yahoo.com/news/apple-rival-opp...  Bloomberg     -0.21
# 4    https://finance.yahoo.com/news/apple-google-ri...  Bloomberg      0.59
# 5    https://finance.yahoo.com/news/uk-regulator-co...    Reuters      0.59
# 6    https://finance.yahoo.com/news/india-rejects-a...  Bloomberg       NaN
# 7    https://finance.yahoo.com/news/indian-regulato...    Reuters       NaN
# 8    https://finance.yahoo.com/news/apple-chief-ret...  Bloomberg      1.31
# 9    https://finance.yahoo.com/news/indonesia-says-...    Reuters      1.31
# 10   https://finance.yahoo.com/news/irish-pm-harris...  Bloomberg       NaN
# 11   https://finance.yahoo.com/news/apple-accused-s...    Reuters      0.95
# 12   https://finance.yahoo.com/news/indonesia-expec...    Reuters      1.28
# 13   https://finance.yahoo.com/news/indonesia-says-...  Bloomberg      1.28
# 14   https://finance.yahoo.com/news/apple-facing-hu...    Reuters      0.15
# 15   https://finance.yahoo.com/news/trump-taps-vanc...  Bloomberg      0.15
# 16   https://finance.yahoo.com/news/iphone-maker-ho...  Bloomberg      0.01
# 17   https://finance.yahoo.com/news/apple-plans-thr...    Reuters     -0.08
# 18   https://finance.yahoo.com/news/apple-prepares-...  Bloomberg     -0.08
# 19   https://finance.yahoo.com/m/1f3de1b0-7e88-3068...  Bloomberg      1.61
# 20   https://finance.yahoo.com/news/apple-rally-una...  Bloomberg      0.41
# 21   https://finance.yahoo.com/news/apple-next-ultr...  Bloomberg      0.41
# 22   https://finance.yahoo.com/m/9245aa07-2a43-3e68...    Reuters      0.41
# 23   https://finance.yahoo.com/m/be431eae-b710-356f...    Reuters     -0.52
# 24   https://finance.yahoo.com/news/uk-pm-starmer-m...    Reuters     -0.52
# 25   https://finance.yahoo.com/news/google-unveils-...  Bloomberg      0.60
# 26   https://finance.yahoo.com/news/apple-nears-swi...    Reuters      0.60
# 27   https://finance.yahoo.com/news/broadcom-shares...  Bloomberg      0.60
# 28   https://finance.yahoo.com/news/xiaomi-103-rall...  Bloomberg      0.60
# 29   https://finance.yahoo.com/news/xiaomi-103-rall...  Bloomberg      0.07
# 30   https://finance.yahoo.com/news/broadcom-shares...  Bloomberg      0.07
# 31   https://finance.yahoo.com/news/apple-ceo-tim-c...    Reuters      0.07
# 32   https://finance.yahoo.com/m/848f29e4-93a2-3ccf...    Reuters      1.17
# 33   https://finance.yahoo.com/m/0df2fb00-491b-366a...    Reuters      0.97
# 34   https://finance.yahoo.com/news/arm-qualcomm-la...    Reuters      0.97
# 35   https://finance.yahoo.com/news/eu-escalates-pr...  Bloomberg     -2.14
# 36   https://finance.yahoo.com/news/apple-talks-ten...    Reuters     -2.14
# 37   https://finance.yahoo.com/news/apple-1-billion...  Bloomberg       NaN
# 38   https://finance.yahoo.com/news/apple-approache...    Reuters      0.31
# 39   https://finance.yahoo.com/news/tesla-meta-broa...  Bloomberg      0.31
# 40   https://finance.yahoo.com/news/apple-seeks-def...    Reuters      1.15
# 41   https://finance.yahoo.com/news/nvidias-market-...    Reuters     -2.62
# 42   https://finance.yahoo.com/news/apple-pay-95-mi...    Reuters     -2.62
# 43   https://finance.yahoo.com/news/apple-offers-ip...    Reuters     -2.62
# 44   https://finance.yahoo.com/news/chipmaker-imagi...  Bloomberg     -0.20
# 45   https://finance.yahoo.com/news/foreign-smartph...    Reuters     -0.20
# 46   https://finance.yahoo.com/news/nvidia-partner-...  Bloomberg       NaN
# 47   https://finance.yahoo.com/m/7493e9cd-73c4-379b...  Bloomberg      0.67
# 48   https://finance.yahoo.com/news/dell-unveils-ap...  Bloomberg      0.67
# 49   https://finance.yahoo.com/news/apple-faces-tou...  Bloomberg     -1.14
# 50   https://finance.yahoo.com/news/indonesia-meet-...    Reuters     -1.14
# 51   https://finance.yahoo.com/news/apple-clarifies...    Reuters      0.20
# 52   https://finance.yahoo.com/news/microsoft-googl...  Bloomberg       NaN
# 53   https://finance.yahoo.com/news/tsmc-sales-beat...  Bloomberg     -2.41
# 54   https://finance.yahoo.com/m/0babc658-05a2-3ba1...  Bloomberg     -2.41
# 55   https://finance.yahoo.com/news/apple-ceo-pay-r...  Bloomberg     -2.41
# 56   https://finance.yahoo.com/news/apples-board-re...    Reuters       NaN
# 57   https://finance.yahoo.com/news/apple-fights-1-...    Reuters     -1.03
# 58   https://finance.yahoo.com/news/exclusive-tech-...    Reuters     -1.03
# 59   https://finance.yahoo.com/news/apples-fees-app...    Reuters     -1.03
# 60   https://finance.yahoo.com/news/iphone-loses-gl...  Bloomberg     -1.03
# 61   https://finance.yahoo.com/news/apple-samsung-s...    Reuters     -1.03
# 62   https://ca.finance.yahoo.com/news/tiktok-ban-w...    Reuters     -4.04
# 63   https://finance.yahoo.com/news/tsmc-profit-bea...  Bloomberg     -4.04
# 64   https://finance.yahoo.com/news/microsoft-stock...  Bloomberg      0.75
# 65   https://finance.yahoo.com/m/591ce64f-1bbf-34fd...  Bloomberg      0.75
# 66   https://finance.yahoo.com/m/591ce64f-1bbf-34fd...  Bloomberg      0.75
# 67   https://finance.yahoo.com/news/apple-iphone-sa...  Bloomberg       NaN
# 68   https://finance.yahoo.com/news/tiktok-app-unav...    Reuters     -3.19
# 69   https://finance.yahoo.com/news/meta-plans-oakl...  Bloomberg     -3.19
# 70   https://finance.yahoo.com/news/apple-tough-jan...  Bloomberg     -3.19
# 71   https://finance.yahoo.com/news/swedish-spam-bl...  Bloomberg     -3.19
# 72   https://finance.yahoo.com/news/nasdaq-100-hist...  Bloomberg      0.53
# 73   https://finance.yahoo.com/news/indonesia-close...    Reuters      0.53
# 74   https://ca.finance.yahoo.com/news/indonesia-cl...    Reuters      0.53
# 75   https://finance.yahoo.com/news/samsung-set-ent...  Bloomberg      0.53
# 76   https://finance.yahoo.com/news/samsung-beat-ap...  Bloomberg      0.53
# 77   https://finance.yahoo.com/news/exclusive-india...    Reuters      0.53
# 78   https://finance.yahoo.com/m/5f6593fb-35f6-3e83...    Reuters     -0.08
# 79   https://finance.yahoo.com/news/uk-investigate-...    Reuters     -0.08
# 80   https://finance.yahoo.com/news/apple-google-hi...  Bloomberg     -0.08
# 81   https://finance.yahoo.com/news/oracle-takes-ru...  Bloomberg     -0.08
# 82   https://finance.yahoo.com/news/apple-close-dea...  Bloomberg     -0.08
# 83   https://finance.yahoo.com/news/epic-games-ramp...  Bloomberg     -0.08
# 84   https://finance.yahoo.com/m/40fbdf60-0d08-3198...    Reuters     -0.08
# 85   https://finance.yahoo.com/news/epic-games-kick...    Reuters     -0.08
# 86   https://finance.yahoo.com/news/apple-enlists-v...  Bloomberg     -0.39
# 87   https://finance.yahoo.com/m/5b9f0567-241f-3c39...  Bloomberg     -0.39
# 88   https://finance.yahoo.com/news/apple-tests-key...  Bloomberg     -0.39
# 89   https://finance.yahoo.com/news/wall-street-opt...  Bloomberg      3.18
# 90   https://finance.yahoo.com/news/morning-bid-ai-...    Reuters      3.18
# 91   https://finance.yahoo.com/m/cda861d8-070b-3c62...    Reuters      3.65
# 92   https://finance.yahoo.com/news/apples-sales-li...    Reuters      0.46
# 93   https://finance.yahoo.com/news/apple-spacex-su...  Bloomberg      0.46
# 94   https://finance.yahoo.com/m/105ab3a5-cc40-3b2c...    Reuters      0.46
# 95   https://finance.yahoo.com/m/105ab3a5-cc40-3b2c...    Reuters      0.46
# 96   https://finance.yahoo.com/news/apple-gets-anot...  Bloomberg      0.46
# 97   https://finance.yahoo.com/news/rba-ramps-scrut...  Bloomberg     -0.74
# 98   https://finance.yahoo.com/news/apple-flagging-...  Bloomberg     -0.74
# 99   https://finance.yahoo.com/news/apple-profit-to...    Reuters     -0.74
# 100  https://finance.yahoo.com/news/apple-reports-s...  Bloomberg     -0.74
# 101  https://finance.yahoo.com/news/apple-lifts-us-...    Reuters     -0.67
# 102  https://finance.yahoo.com/news/apple-reports-s...  Bloomberg     -0.67
# 103  https://finance.yahoo.com/news/apple-scraps-ma...  Bloomberg     -0.67
# 104  https://finance.yahoo.com/m/5205ff42-1064-3121...    Reuters     -3.39
# 105  https://finance.yahoo.com/m/ec955a2e-c9c9-3747...  Bloomberg      2.10
# 106  https://finance.yahoo.com/news/apple-debuts-in...  Bloomberg      2.10
# 107  https://finance.yahoo.com/news/china-mulling-p...    Reuters     -0.14
# 108  https://finance.yahoo.com/news/youtube-buying-...  Bloomberg      0.32
# 109  https://finance.yahoo.com/news/apple-china-foc...  Bloomberg      0.32
# 110  https://finance.yahoo.com/news/qualcomm-falls-...  Bloomberg      0.32
# 111  https://finance.yahoo.com/news/apple-long-awai...  Bloomberg      0.32
# 112  https://finance.yahoo.com/m/7bd98de3-fcc0-3f42...  Bloomberg     -2.40
# 113  https://finance.yahoo.com/m/aa04d1b8-e428-31db...  Bloomberg     -2.40
#
#         hits
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       NaN
# 11       NaN
# 12       NaN
# 13       NaN
# 14       NaN
# 15       NaN
# 16       NaN
# 17       NaN
# 18       NaN
# 19       NaN
# 20       NaN
# 21       NaN
# 22       NaN
# 23       NaN
# 24       NaN
# 25       NaN
# 26       NaN
# 27       NaN
# 28       NaN
# 29       NaN
# 30       NaN
# 31       NaN
# 32       NaN
# 33       NaN
# 34       NaN
# 35       NaN
# 36       NaN
# 37       NaN
# 38       NaN
# 39       NaN
# 40       NaN
# 41       NaN
# 42       NaN
# 43       NaN
# 44       NaN
# 45       NaN
# 46       NaN
# 47       NaN
# 48       NaN
# 49       NaN
# 50       NaN
# 51       NaN
# 52       NaN
# 53       NaN
# 54       NaN
# 55       NaN
# 56       NaN
# 57       NaN
# 58       NaN
# 59       NaN
# 60       NaN
# 61       NaN
# 62     675.0
# 63       3.0
# 64       NaN
# 65       NaN
# 66       NaN
# 67       NaN
# 68       NaN
# 69       NaN
# 70       NaN
# 71       NaN
# 72       NaN
# 73       NaN
# 74       NaN
# 75       NaN
# 76       NaN
# 77       NaN
# 78       NaN
# 79       NaN
# 80       NaN
# 81       NaN
# 82       NaN
# 83       NaN
# 84       NaN
# 85       NaN
# 86       NaN
# 87       NaN
# 88       NaN
# 89       NaN
# 90       NaN
# 91    3090.0
# 92       NaN
# 93       NaN
# 94       NaN
# 95       NaN
# 96       NaN
# 97       NaN
# 98       NaN
# 99       NaN
# 100      NaN
# 101      NaN
# 102      NaN
# 103      NaN
# 104  45300.0
# 105      NaN
# 106      NaN
# 107      NaN
# 108      NaN
# 109      NaN
# 110      NaN
# 111      NaN
# 112      NaN
# 113      NaN

# %%
# if snapshot[['Date', 'Title', 'Link', 'Source']].equals(news_df[['Date', 'Title', 'Link', 'Source']]):      
#     news_df.to_csv(file, index = False)
# else: 
#     raise Exception('unsafe to overwrite news_df')

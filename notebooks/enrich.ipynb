# %% [markdown]
# This notebook enriches `stock` news sources with price movement (price change during date of publish), and search hits. (how 'popular' a news article was)

# %%
import logging
import requests 
from datetime import timedelta, datetime
import time
import pandas as pd
import yfinance as yf 
from bs4 import BeautifulSoup
import requests
import re 
import os
from config import * 

stock = 'TSLA'

# lookup stock in file 
file = f'{STOCK_PATH}/{stock}.csv'
news = pd.read_csv(file, parse_dates=['Date'])


pd.set_option('display.max_rows', None)  # Display all rows
pd.set_option('display.max_columns', None)  # Display all columns

news['Date']
# Out:
# 0    2024-11-25 15:53:00
# 1    2024-11-25 10:48:00
# 2    2024-11-25 10:20:00
# 3    2024-11-26 05:36:00
# 4    2024-11-27 02:38:00
# 5    2024-11-29 02:57:00
# 6    2024-11-29 21:48:00
# 7    2024-11-30 10:12:00
# 8    2024-12-09 14:00:00
# 9    2024-12-09 21:41:00
# 10   2024-12-10 02:12:00
# 11   2024-12-10 11:50:00
# 12   2024-12-10 19:49:00
# 13   2024-12-10 22:30:00
# 14   2024-12-11 09:40:00
# 15   2024-12-11 12:19:00
# 16   2024-12-11 16:12:00
# 17   2024-12-11 17:11:00
# 18   2024-12-12 09:36:00
# 19   2024-12-12 21:50:00
# 20   2024-12-13 02:59:00
# 21   2024-12-13 06:09:00
# 22   2024-12-13 07:27:00
# 23   2024-12-13 12:02:00
# 24   2024-12-13 14:11:00
# 25   2024-12-13 15:43:00
# 26   2024-12-13 17:06:00
# 27   2024-12-16 06:07:00
# 28   2024-12-16 18:25:00
# 29   2024-12-17 11:36:00
# 30   2024-12-17 21:13:00
# 31   2024-12-18 02:15:00
# 32   2024-12-19 07:29:00
# 33   2024-12-20 05:42:00
# 34   2024-12-20 06:02:00
# 35   2024-12-20 17:24:00
# 36   2024-12-21 08:00:00
# 37   2024-12-23 08:41:00
# 38   2024-12-23 14:08:00
# 39   2024-12-27 06:05:00
# 40   2024-12-30 23:20:00
# 41   2024-12-31 04:32:00
# 42   2024-12-31 07:50:00
# 43   2025-01-01 16:12:00
# 44   2025-01-01 16:12:00
# 45   2025-01-01 16:12:00
# 46   2025-01-02 06:03:00
# 47   2025-01-02 09:07:00
# 48   2025-01-02 10:53:00
# 49   2025-01-02 12:07:00
# 50   2025-01-02 21:49:00
# 51   2025-01-03 04:52:00
# 52   2025-01-03 06:07:00
# 53   2025-01-06 23:16:00
# 54   2025-01-07 06:00:00
# 55   2025-01-07 06:55:00
# 56   2025-01-07 08:52:00
# 57   2025-01-07 18:00:00
# 58   2025-01-07 18:32:00
# Name: Date, dtype: datetime64[ns]

# %%
# calculate intraday return in yfinance
def get_intraday_return(stock, oldest_date): 
    data = yf.download(stock, period = 'max', start = oldest_date - timedelta(weeks = 1))       # news from [oldest_date, today]
    data.columns = data.columns.droplevel(1)                             # drop the multi-level column index
    data.columns.name = None 

    data['Prev Close'] = data['Close'].shift(1)     # get previous close by shifting it down by 1
    data['% Change'] = ((data['Close'] - data['Prev Close']) / data['Prev Close'])  * 100
    data['% Change'] = data['% Change'].round(2)
    data.sort_values('% Change', ascending = False, inplace = True)
    return data

swings = get_intraday_return(stock, news['Date'].min())               # largest % price changes 

def lookup_date(timestamp):
    '''Looks up the price movement on a given date and populates news df'''
    try:
        return swings.loc[str(timestamp.date()), '% Change']
    except KeyError:
        return None     # print(f'No price movement data for {timestamp.date()}')

news['% Change'] = news['Date'].apply(lookup_date)         

news
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Date                                              Title  \
# 0  2024-11-25 15:53:00  Tesla Excluded From EV Buyer Credits in Califo...
# 1  2024-11-25 10:48:00  Tesla racked up greenhouse emissions credits i...
# 2  2024-11-25 10:20:00  Teslas $350 Billion Stock Surge Driven by Anim...
# 3  2024-11-26 05:36:00                Trump eyes "AI czar", Axios reports
# 4  2024-11-27 02:38:00  Lidar Maker Hesai Sees Device Becoming as Comm...
# 5  2024-11-29 02:57:00  India to expand EV manufacturing incentives af...
# 6  2024-11-29 21:48:00  JPMorgan agrees to drop lawsuit against Tesla ...
# 7  2024-11-30 10:12:00  JPMorgan Drops Suit Against Tesla Over Musk Tw...
# 8  2024-12-09 14:00:00  Tesla aims to launch robotaxi with teleoperato...
# 9  2024-12-09 21:41:00  Xiaomi Teases Tesla-Like SUV for Summer in Big...
# 10 2024-12-10 02:12:00  Xiaomi Teases Tesla-Like SUV for Summer in Big...
# 11 2024-12-10 11:50:00  Tesla restarts search for New Delhi showroom w...
# 12 2024-12-10 19:49:00  GM Calls It Quits on Mary Barras $50 Billion R...
# 13 2024-12-10 22:30:00  Tesla sells 21,900 EVs in China in first week ...
# 14 2024-12-11 09:40:00  GM Calls It Quits on Mary Barras $50 Billion R...
# 15 2024-12-11 12:19:00                   Tesla shares jump to record high
# 16 2024-12-11 16:12:00  Tesla Shares Jump to Record Amid $515 Billion ...
# 17 2024-12-11 17:11:00  Elon Musks Net Worth Tops $400 Billion, a Hist...
# 18 2024-12-12 09:36:00  Elon Musk's net worth tops $400 billion, Forbe...
# 19 2024-12-12 21:50:00  Musk Ups SEC Feud by Posting Letter Disclosing...
# 20 2024-12-13 02:59:00  Tesla launches 'Actually Smart Summon' feature...
# 21 2024-12-13 06:09:00  Exclusive-Trump transition recommends scrappin...
# 22 2024-12-13 07:27:00  A 500% rally shows the Elon Musk euphoria for ...
# 23 2024-12-13 12:02:00  Musk Ups SEC Feud Over Neuralink Probe, Twitte...
# 24 2024-12-13 14:11:00  Fee War Kicks Off for One of Wall Streets Hott...
# 25 2024-12-13 15:43:00                       Musk Euphoria Benefits Funds
# 26 2024-12-13 17:06:00  Judge clears way for Musk appeal to try to res...
# 27 2024-12-16 06:07:00  Exclusive-Trump transition team plans sweeping...
# 28 2024-12-16 18:25:00  China resident who stole Tesla trade secrets g...
# 29 2024-12-17 11:36:00  Tesla castigates German union over attempt to ...
# 30 2024-12-17 21:13:00  Honda, Nissan move to closer tie-up as competi...
# 31 2024-12-18 02:15:00  Tesla's China factory head Song Gang leaves co...
# 32 2024-12-19 07:29:00  Tesla in talks with city of Austin over self-d...
# 33 2024-12-20 05:42:00  Tesla recalls nearly 700,000 vehicles in US ov...
# 34 2024-12-20 06:02:00  Tesla's 2024 deliveries growth might hinge on ...
# 35 2024-12-20 17:24:00  House Democrat says Republicans protecting Elo...
# 36 2024-12-21 08:00:00  Musks Trump Trade Makes Tesla a Winner With $5...
# 37 2024-12-23 08:41:00  Trump Efficiency Co-Chief Elon Musk Calls Fed ...
# 38 2024-12-23 14:08:00  Tesla, Meta and Broadcom Weights Shrink in Nas...
# 39 2024-12-27 06:05:00  Ark's Cathie Wood calls for tax clarity as she...
# 40 2024-12-30 23:20:00  Tesla's Shanghai energy storage gigafactory be...
# 41 2024-12-31 04:32:00  Tesla to fix software for 77,650 China-made ve...
# 42 2024-12-31 07:50:00  Tesla stock surge runs up against a potential ...
# 43 2025-01-01 16:12:00  Tesla Cybertruck fire in Las Vegas leaves one ...
# 44 2025-01-01 16:12:00  Tesla Cybertruck explodes outside Trump Las Ve...
# 45 2025-01-01 16:12:00  Musk says Tesla investigating Cybertruck fire ...
# 46 2025-01-02 06:03:00  As Musk gains influence, questions hover over ...
# 47 2025-01-02 09:07:00  Tesla annual deliveries fall for first time as...
# 48 2025-01-02 10:53:00  Teslas Annual EV Sales Drop for First Time in ...
# 49 2025-01-02 12:07:00  Musk donated $108 million in Tesla shares to u...
# 50 2025-01-02 21:49:00  Tesla's China sales rise to record high in 202...
# 51 2025-01-03 04:52:00  Teslas Annual EV Sales Drop for First Time in ...
# 52 2025-01-03 06:07:00  2024 US new-car sales rise to five-year high, ...
# 53 2025-01-06 23:16:00  Tesla supplier Panasonic Energy says cutting C...
# 54 2025-01-07 06:00:00  Musks Massive Tesla Lithium Plant Hunts for Wa...
# 55 2025-01-07 06:55:00  Automakers to pool CO2 emissions with Tesla, M...
# 56 2025-01-07 08:52:00  Tesla seeks Sweden court order in protracted l...
# 57 2025-01-07 18:00:00  How Washington's tag on China's CATL could aff...
# 58 2025-01-07 18:32:00  US Blacklist of Chinas Tech Giants Risks Faste...
#
#                                                  Link     Source  % Change
# 0   https://finance.yahoo.com/news/california-pled...  Bloomberg     -3.96
# 1   https://finance.yahoo.com/news/tesla-racked-gr...    Reuters     -3.96
# 2   https://finance.yahoo.com/news/tesla-350-billi...  Bloomberg     -3.96
# 3   https://finance.yahoo.com/news/trump-eyes-ai-c...    Reuters     -0.11
# 4   https://finance.yahoo.com/news/lidar-maker-hes...  Bloomberg     -1.58
# 5   https://finance.yahoo.com/news/india-expand-ev...    Reuters      3.69
# 6   https://finance.yahoo.com/news/jpmorgan-agrees...    Reuters      3.69
# 7   https://finance.yahoo.com/news/jpmorgan-drops-...  Bloomberg       NaN
# 8   https://finance.yahoo.com/news/tesla-aims-laun...    Reuters      0.15
# 9   https://finance.yahoo.com/news/xiaomi-teases-t...  Bloomberg      0.15
# 10  https://finance.yahoo.com/news/xiaomi-teases-t...  Bloomberg      2.87
# 11  https://finance.yahoo.com/news/tesla-restarts-...    Reuters      2.87
# 12  https://finance.yahoo.com/news/gm-calls-quits-...  Bloomberg      2.87
# 13  https://finance.yahoo.com/news/tesla-sells-21-...    Reuters      2.87
# 14  https://finance.yahoo.com/news/gm-calls-quits-...  Bloomberg      5.93
# 15  https://finance.yahoo.com/news/tesla-shares-ju...    Reuters      5.93
# 16  https://finance.yahoo.com/news/tesla-shares-ju...  Bloomberg      5.93
# 17  https://finance.yahoo.com/news/elon-musk-net-w...  Bloomberg      5.93
# 18  https://finance.yahoo.com/news/elon-musks-net-...    Reuters     -1.57
# 19  https://finance.yahoo.com/news/musk-ups-sec-fe...  Bloomberg     -1.57
# 20  https://finance.yahoo.com/news/tesla-launches-...    Reuters      4.34
# 21  https://finance.yahoo.com/m/7630ec69-2bc6-31c1...    Reuters      4.34
# 22  https://finance.yahoo.com/news/500-rally-shows...  Bloomberg      4.34
# 23  https://finance.yahoo.com/news/musk-ups-sec-fe...  Bloomberg      4.34
# 24  https://finance.yahoo.com/news/fee-war-kicks-o...  Bloomberg      4.34
# 25  https://finance.yahoo.com/video/musk-euphoria-...  Bloomberg      4.34
# 26  https://finance.yahoo.com/news/judge-clears-wa...    Reuters      4.34
# 27  https://finance.yahoo.com/m/d85b6f9c-9173-378e...    Reuters      6.14
# 28  https://finance.yahoo.com/news/china-resident-...    Reuters      6.14
# 29  https://finance.yahoo.com/news/tesla-castigate...    Reuters      3.64
# 30  https://finance.yahoo.com/news/honda-nissan-mo...    Reuters      3.64
# 31  https://finance.yahoo.com/news/teslas-china-fa...    Reuters     -8.28
# 32  https://finance.yahoo.com/news/tesla-talks-cit...    Reuters     -0.90
# 33  https://finance.yahoo.com/news/tesla-recalls-n...    Reuters     -3.46
# 34  https://finance.yahoo.com/news/teslas-2024-del...    Reuters     -3.46
# 35  https://finance.yahoo.com/news/house-democrat-...    Reuters     -3.46
# 36  https://finance.yahoo.com/news/musk-trump-trad...  Bloomberg       NaN
# 37  https://finance.yahoo.com/news/elon-musk-makes...  Bloomberg      2.27
# 38  https://finance.yahoo.com/news/tesla-meta-broa...  Bloomberg      2.27
# 39  https://finance.yahoo.com/news/arks-cathie-woo...    Reuters     -4.95
# 40  https://finance.yahoo.com/news/teslas-shanghai...    Reuters     -3.30
# 41  https://finance.yahoo.com/news/tesla-fix-softw...    Reuters     -3.25
# 42  https://finance.yahoo.com/news/tesla-stock-sur...  Bloomberg     -3.25
# 43  https://finance.yahoo.com/m/09317afb-70aa-325d...    Reuters       NaN
# 44  https://finance.yahoo.com/m/09317afb-70aa-325d...    Reuters       NaN
# 45  https://finance.yahoo.com/news/musk-says-tesla...    Reuters       NaN
# 46  https://finance.yahoo.com/news/musk-gains-infl...    Reuters     -6.08
# 47  https://finance.yahoo.com/news/teslas-posts-fi...    Reuters     -6.08
# 48  https://finance.yahoo.com/news/tesla-annual-ev...  Bloomberg     -6.08
# 49  https://finance.yahoo.com/news/musk-donated-10...    Reuters     -6.08
# 50  https://finance.yahoo.com/news/teslas-china-sa...    Reuters     -6.08
# 51  https://finance.yahoo.com/news/tesla-annual-ev...  Bloomberg      8.22
# 52  https://finance.yahoo.com/news/consumers-boost...    Reuters      8.22
# 53  https://finance.yahoo.com/news/tesla-supplier-...    Reuters      0.15
# 54  https://finance.yahoo.com/news/musk-massive-te...  Bloomberg     -4.06
# 55  https://finance.yahoo.com/news/stellantis-toyo...    Reuters     -4.06
# 56  https://finance.yahoo.com/news/tesla-seeks-swe...    Reuters     -4.06
# 57  https://finance.yahoo.com/news/washingtons-tag...    Reuters     -4.06
# 58  https://finance.yahoo.com/m/28a2bf67-ec2b-3751...  Bloomberg     -4.06

# %%
def get_google_results(query):      # using google Custom Search JSON API
    params = {
        'q': f'"{query}"',
        'key': GOOGLE_API_KEY, 
        'cx': SEARCH_ENGINE_ID,         
    }

    try: 
        response = requests.get('https://www.googleapis.com/customsearch/v1', params = params).json() 
        if 'totalResults' not in response['queries']['request'][0]: return 0 
        num_results = int(response['queries']['request'][0]['totalResults'])
        print(query, num_results)
        return num_results
    
    except Exception as e:
        print(response)
        raise e

    
'''
Mines the top N days with the highest price change for news catalysts
'''
n = 4           # set this to a low number because of google api limits :)
largest_price_changes = news['% Change'].sort_values(key=abs, ascending=False).drop_duplicates().head(n)
news.loc[news['% Change'].isin(largest_price_changes), 'hits'] = news.loc[news['% Change'].isin(largest_price_changes), 'Title'].apply(get_google_results)
# Out:
# Exclusive-Trump transition team plans sweeping rollback of Biden EV, emissions policies 2220
# China resident who stole Tesla trade secrets gets 2-year US sentence 1840
# Tesla's China factory head Song Gang leaves company, letter to staff shows 617
# As Musk gains influence, questions hover over US probes into his empire 34100
# Tesla annual deliveries fall for first time as competition hurts demand 9690
# Teslas Annual EV Sales Drop for First Time in Over a Decade 40
# Musk donated $108 million in Tesla shares to unnamed charities, filing shows 4510
# Tesla's China sales rise to record high in 2024, bucking global decline 9400
# Teslas Annual EV Sales Drop for First Time in Over a Decade 40
# 2024 US new-car sales rise to five-year high, but Tesla and Stellantis lag 328

# %%
news[news['hits'] == news['hits'].max()]
# Out:
#                   Date                                              Title  \
# 46 2025-01-02 06:03:00  As Musk gains influence, questions hover over ...
#
#                                                  Link   Source  % Change  \
# 46  https://finance.yahoo.com/news/musk-gains-infl...  Reuters     -6.08
#
#        hits
# 46  34100.0

# %%
# write back enriched news data back to csv 
news.to_csv(f'{OUTPUT_STOCK_PATH}/{stock}.csv', index = False)
